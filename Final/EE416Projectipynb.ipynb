# %%
import random
import csv
import os
import os.path
import shutil
import cv2

import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm # Displays a progress bar

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import Dataset, Subset, DataLoader, random_split, ConcatDataset
import torchvision.models as models
import tqdm.notebook as tq

import pandas as pd
import h5py
import math

# %%
############
# Download Data from Google Drive
############
# %cd /content
# !gdown https://drive.google.com/uc?id=1olKESqgAm5GeAmuRC21BpTBkxFrgmUIp
# !unzip /content/Data

print("Finished Downloading data")
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Data/Covid/16858.png
#   inflating: Data/Covid/16859.png
#   inflating: Data/Covid/16872.png
#   inflating: Data/Covid/16878.png
#   inflating: Data/Covid/16895.png
#   inflating: Data/Covid/16899.png
#   inflating: Data/Covid/16905.png
#   inflating: Data/Covid/16917.png
#   inflating: Data/Covid/16925.png
#   inflating: Data/Covid/16928.png
#   inflating: Data/Covid/16935.png
#   inflating: Data/Covid/16940.png
#   inflating: Data/Covid/16944.png
#   inflating: Data/Covid/16954.png
#   inflating: Data/Covid/16958.png
#   inflating: Data/Covid/17014.png
#   inflating: Data/Covid/17039.png
#   inflating: Data/Covid/17040.png
#   inflating: Data/Covid/17058.png
#   inflating: Data/Covid/17078.png
#   inflating: Data/Covid/17079.png
#   inflating: Data/Covid/17105.png
#   inflating: Data/Covid/17110.png
#   inflating: Data/Covid/17130.png
#   inflating: Data/Covid/17137.png
#   inflating: Data/Covid/17164.png
#   inflating: Data/Covid/17165.png
#   inflating: Data/Covid/17170.png
#   inflating: Data/Covid/17177.png
#   inflating: Data/Covid/17188.png
#   inflating: Data/Covid/17189.png
#   inflating: Data/Covid/17195.png
#   inflating: Data/Covid/17205.png
#   inflating: Data/Covid/17217.png
#   inflating: Data/Covid/17238.png
#   inflating: Data/Covid/17253.png
#   inflating: Data/Covid/17257.png
#   inflating: Data/Covid/17284.png
#   inflating: Data/Covid/17289.png
#   inflating: Data/Covid/17324.png
#   inflating: Data/Covid/17330.png
#   inflating: Data/Covid/17344.png
#   inflating: Data/Covid/17357.png
#   inflating: Data/Covid/17378.png
#   inflating: Data/Covid/17402.png
#   inflating: Data/Covid/17407.png
#   inflating: Data/Covid/17412.png
#   inflating: Data/Covid/17417.png
#   inflating: Data/Covid/17425.png
#   inflating: Data/Covid/17430.png
#   inflating: Data/Covid/17433.png
#   inflating: Data/Covid/17443.png
#   inflating: Data/Covid/17459.png
#   inflating: Data/Covid/17462.png
#   inflating: Data/Covid/17492.png
#   inflating: Data/Covid/17502.png
#   inflating: Data/Covid/17535.png
#   inflating: Data/Covid/17553.png
#   inflating: Data/Covid/17557.png
#   inflating: Data/Covid/17558.png
#   inflating: Data/Covid/17562.png
#   inflating: Data/Covid/17567.png
#   inflating: Data/Covid/17580.png
#   inflating: Data/Covid/17590.png
#   inflating: Data/Covid/17592.png
#   inflating: Data/Covid/17593.png
#   inflating: Data/Covid/17607.png
#   inflating: Data/Covid/17608.png
#   inflating: Data/Covid/17620.png
#   inflating: Data/Covid/17627.png
#   inflating: Data/Covid/17635.png
#   inflating: Data/Covid/17655.png
#   inflating: Data/Covid/17662.png
#   inflating: Data/Covid/17682.png
#   inflating: Data/Covid/17683.png
#   inflating: Data/Covid/17704.png
#   inflating: Data/Covid/17705.png
#   inflating: Data/Covid/17708.png
#   inflating: Data/Covid/17710.png
#   inflating: Data/Covid/17714.png
#   inflating: Data/Covid/17715.png
#   inflating: Data/Covid/17718.png
#   inflating: Data/Covid/17728.png
#   inflating: Data/Covid/17740.png
#   inflating: Data/Covid/17770.png
#   inflating: Data/Covid/17772.png
#   inflating: Data/Covid/17799.png
#   inflating: Data/Covid/17800.png
#   inflating: Data/Covid/17814.png
#   inflating: Data/Covid/17819.png
#   inflating: Data/Covid/17825.png
#   inflating: Data/Covid/17829.png
#   inflating: Data/Covid/17838.png
#   inflating: Data/Covid/17870.png
#   inflating: Data/Covid/17877.png
#   inflating: Data/Covid/17880.png
#   inflating: Data/Covid/17890.png
#   inflating: Data/Covid/17900.png
#   inflating: Data/Covid/17910.png
#   inflating: Data/Covid/17923.png
#   inflating: Data/Covid/17929.png
#   inflating: Data/Covid/17939.png
#   inflating: Data/Covid/17949.png
#   inflating: Data/Covid/17952.png
#   inflating: Data/Covid/17954.png
#   inflating: Data/Covid/17968.png
#   inflating: Data/Covid/17970.png
#   inflating: Data/Covid/17979.png
#   inflating: Data/Covid/17980.png
#   inflating: Data/Covid/17989.png
#   inflating: Data/Covid/17994.png
#   inflating: Data/Covid/18004.png
#   inflating: Data/Covid/18017.png
#   inflating: Data/Covid/18045.png
#   inflating: Data/Covid/18054.png
#   inflating: Data/Covid/18055.png
#   inflating: Data/Covid/18065.png
#   inflating: Data/Covid/18087.png
#   inflating: Data/Covid/18088.png
#   inflating: Data/Covid/18105.png
#   inflating: Data/Covid/18160.png
#   inflating: Data/Covid/18177.png
#   inflating: Data/Covid/18184.png
#   inflating: Data/Covid/18185.png
#   inflating: Data/Covid/18187.png
#   inflating: Data/Covid/18188.png
#   inflating: Data/Covid/18205.png
#   inflating: Data/Covid/18220.png
#   inflating: Data/Covid/18228.png
#   inflating: Data/Covid/18243.png
#   inflating: Data/Covid/18244.png
#   inflating: Data/Covid/18252.png
#   inflating: Data/Covid/18254.png
#   inflating: Data/Covid/18260.png
#   inflating: Data/Covid/18267.png
#   inflating: Data/Covid/18278.png
#   inflating: Data/Covid/18280.png
#   inflating: Data/Covid/18308.png
#   inflating: Data/Covid/18310.png
#   inflating: Data/Covid/18315.png
#   inflating: Data/Covid/18334.png
#   inflating: Data/Covid/18335.png
#   inflating: Data/Covid/18339.png
#   inflating: Data/Covid/18348.png
#   inflating: Data/Covid/18362.png
#   inflating: Data/Covid/18368.png
#   inflating: Data/Covid/18370.png
#   inflating: Data/Covid/18378.png
#   inflating: Data/Covid/18389.png
#   inflating: Data/Covid/18410.png
#   inflating: Data/Covid/18420.png
#   inflating: Data/Covid/18453.png
#   inflating: Data/Covid/18479.png
#   inflating: Data/Covid/18480.png
#   inflating: Data/Covid/18489.png
#   inflating: Data/Covid/18498.png
#   inflating: Data/Covid/18505.png
#   inflating: Data/Covid/18524.png
#   inflating: Data/Covid/18539.png
#   inflating: Data/Covid/18560.png
#   inflating: Data/Covid/18567.png
#   inflating: Data/Covid/18575.png
#   inflating: Data/Covid/18593.png
#   inflating: Data/Covid/18618.png
#   inflating: Data/Covid/18642.png
#   inflating: Data/Covid/18663.png
#   inflating: Data/Covid/18668.png
#   inflating: Data/Covid/18679.png
#   inflating: Data/Covid/18684.png
#   inflating: Data/Covid/18692.png
#   inflating: Data/Covid/18719.png
#   inflating: Data/Covid/18728.png
#   inflating: Data/Covid/18740.png
#   inflating: Data/Covid/18763.png
#   inflating: Data/Covid/18774.png
#   inflating: Data/Covid/18778.png
#   inflating: Data/Covid/18798.png
#   inflating: Data/Covid/18800.png
#   inflating: Data/Covid/18802.png
#   inflating: Data/Covid/18803.png
#   inflating: Data/Covid/18810.png
#   inflating: Data/Covid/18819.png
#   inflating: Data/Covid/18825.png
#   inflating: Data/Covid/18857.png
#   inflating: Data/Covid/18869.png
#   inflating: Data/Covid/18873.png
#   inflating: Data/Covid/18877.png
#   inflating: Data/Covid/18880.png
#   inflating: Data/Covid/18930.png
#   inflating: Data/Covid/18934.png
#   inflating: Data/Covid/18954.png
#   inflating: Data/Covid/18958.png
#   inflating: Data/Covid/18969.png
#   inflating: Data/Covid/18979.png
#   inflating: Data/Covid/18980.png
#   inflating: Data/Covid/18987.png
#   inflating: Data/Covid/18993.png
#   inflating: Data/Covid/18994.png
#   inflating: Data/Covid/19003.png
#   inflating: Data/Covid/19018.png
#   inflating: Data/Covid/19025.png
#   inflating: Data/Covid/15781.png
#   inflating: Data/Covid/17706.png
#   inflating: Data/Covid/18231.png
#   inflating: Data/Covid/18471.png
#   inflating: Data/Covid/13166.png
#   inflating: Data/Covid/14461.png
#   inflating: Data/Covid/10696.png
#   inflating: Data/Covid/13071.png
#   inflating: Data/Covid/11031.png
#   inflating: Data/Covid/16721.png
#   inflating: Data/Covid/17391.png
#   inflating: Data/Covid/18886.png
#   inflating: Data/Covid/17596.png
#   inflating: Data/Covid/12806.png
#   inflating: Data/Covid/13981.png
#   inflating: Data/Covid/10471.png
#   inflating: Data/Covid/16431.png
#   inflating: Data/Covid/11411.png
#   inflating: Data/Covid/14586.png
#   inflating: Data/Covid/15831.png
#   inflating: Data/Covid/14091.png
#   inflating: Data/Covid/13061.png
#   inflating: Data/Covid/11871.png
#   inflating: Data/Covid/11891.png
#   inflating: Data/Covid/10736.png
#   inflating: Data/Covid/10466.png
#   inflating: Data/Covid/11651.png
#   inflating: Data/Covid/15196.png
#   inflating: Data/Covid/17551.png
#   inflating: Data/Covid/17886.png
#   inflating: Data/Covid/17751.png
#   inflating: Data/Covid/12446.png
#   inflating: Data/Covid/15471.png
#   inflating: Data/Covid/10206.png
#   inflating: Data/Covid/12306.png
#   inflating: Data/Covid/15176.png
#   inflating: Data/Covid/18366.png
#   inflating: Data/Covid/16781.png
#   inflating: Data/Covid/13841.png
#   inflating: Data/Covid/11991.png
#   inflating: Data/Covid/17736.png
#   inflating: Data/Covid/13241.png
#   inflating: Data/Covid/13781.png
#   inflating: Data/Covid/12476.png
#   inflating: Data/Covid/11691.png
#   inflating: Data/Covid/14206.png
#   inflating: Data/Covid/16196.png
#   inflating: Data/Covid/16701.png
#   inflating: Data/Covid/10286.png
#   inflating: Data/Covid/17361.png
#   inflating: Data/Covid/12521.png
#   inflating: Data/Covid/14376.png
#   inflating: Data/Covid/15111.png
#   inflating: Data/Covid/17396.png
#   inflating: Data/Covid/18696.png
#   inflating: Data/Covid/10996.png
#   inflating: Data/Covid/10681.png
#   inflating: Data/Covid/13316.png
#   inflating: Data/Covid/11296.png
#   inflating: Data/Covid/10706.png
#   inflating: Data/Covid/17206.png
#   inflating: Data/Covid/12066.png
#   inflating: Data/Covid/13271.png
#   inflating: Data/Covid/17056.png
#   inflating: Data/Covid/10081.png
#   inflating: Data/Covid/15741.png
#   inflating: Data/Covid/18796.png
#   inflating: Data/Covid/18086.png
#   inflating: Data/Covid/14881.png
#   inflating: Data/Covid/11696.png
#   inflating: Data/Covid/15431.png
#   inflating: Data/Covid/18466.png
#   inflating: Data/Covid/12816.png
#   inflating: Data/Covid/17411.png
#   inflating: Data/Covid/15351.png
#   inflating: Data/Covid/17146.png
#   inflating: Data/Covid/10721.png
#   inflating: Data/Covid/12431.png
#   inflating: Data/Covid/12141.png
#   inflating: Data/Covid/12946.png
#   inflating: Data/Covid/16366.png
#   inflating: Data/Covid/17181.png
#   inflating: Data/Covid/10111.png
#   inflating: Data/Covid/10586.png
#   inflating: Data/Covid/11211.png
#   inflating: Data/Covid/11681.png
#   inflating: Data/Covid/15311.png
#   inflating: Data/Covid/16436.png
#   inflating: Data/Covid/16471.png
#   inflating: Data/Covid/10616.png
#   inflating: Data/Covid/11436.png
#   inflating: Data/Covid/14386.png
#   inflating: Data/Covid/13376.png
#   inflating: Data/Covid/13701.png
#   inflating: Data/Covid/17926.png
#   inflating: Data/Covid/15756.png
#   inflating: Data/Covid/18711.png
#   inflating: Data/Covid/12351.png
#   inflating: Data/Covid/13406.png
#   inflating: Data/Covid/18931.png
#   inflating: Data/Covid/15716.png
#   inflating: Data/Covid/12111.png
#   inflating: Data/Covid/14546.png
#   inflating: Data/Covid/13206.png
#   inflating: Data/Covid/17351.png
#   inflating: Data/Covid/17281.png
#   inflating: Data/Covid/17476.png
#   inflating: Data/Covid/15601.png
#   inflating: Data/Covid/15761.png
#   inflating: Data/Covid/13366.png
#   inflating: Data/Covid/14501.png
#   inflating: Data/Covid/10906.png
#   inflating: Data/Covid/15121.png
#   inflating: Data/Covid/15331.png
#   inflating: Data/Covid/17031.png
#   inflating: Data/Covid/14821.png
#   inflating: Data/Covid/15091.png
#   inflating: Data/Covid/18691.png
#   inflating: Data/Covid/14871.png
#   inflating: Data/Covid/16986.png
#   inflating: Data/Covid/17881.png
#   inflating: Data/Covid/12561.png
#   inflating: Data/Covid/13451.png
#   inflating: Data/Covid/11791.png
#   inflating: Data/Covid/13636.png
#   inflating: Data/Covid/12416.png
#   inflating: Data/Covid/17976.png
#   inflating: Data/Covid/10921.png
#   inflating: Data/Covid/13556.png
#   inflating: Data/Covid/11106.png
#   inflating: Data/Covid/12531.png
#   inflating: Data/Covid/13686.png
#   inflating: Data/Covid/14841.png
#   inflating: Data/Covid/18496.png
#   inflating: Data/Covid/11346.png
#   inflating: Data/Covid/18816.png
#   inflating: Data/Covid/16006.png
#   inflating: Data/Covid/12516.png
#   inflating: Data/Covid/14956.png
#   inflating: Data/Covid/12096.png
#   inflating: Data/Covid/18256.png
#   inflating: Data/Covid/18846.png
#   inflating: Data/Covid/11111.png
#   inflating: Data/Covid/14836.png
#   inflating: Data/Covid/13951.png
#   inflating: Data/Covid/10746.png
#   inflating: Data/Covid/12566.png
#   inflating: Data/Covid/13256.png
#   inflating: Data/Covid/16826.png
#   inflating: Data/Covid/18646.png
#   inflating: Data/Covid/18511.png
#   inflating: Data/Covid/17386.png
#   inflating: Data/Covid/15456.png
#   inflating: Data/Covid/14636.png
#   inflating: Data/Covid/16776.png
#   inflating: Data/Covid/13416.png
#   inflating: Data/Covid/11721.png
#   inflating: Data/Covid/11896.png
#   inflating: Data/Covid/12811.png
#   inflating: Data/Covid/12466.png
#   inflating: Data/Covid/14596.png
#   inflating: Data/Covid/14776.png
#   inflating: Data/Covid/13821.png
#   inflating: Data/Covid/16711.png
#   inflating: Data/Covid/12406.png
#   inflating: Data/Covid/10896.png
#   inflating: Data/Covid/13501.png
#   inflating: Data/Covid/10596.png
#   inflating: Data/Covid/15586.png
#   inflating: Data/Covid/17081.png
#   inflating: Data/Covid/10611.png
#   inflating: Data/Covid/10411.png
#   inflating: Data/Covid/13661.png
#   inflating: Data/Covid/10676.png
#   inflating: Data/Covid/11616.png
#   inflating: Data/Covid/16046.png
#   inflating: Data/Covid/18376.png
#   inflating: Data/Covid/11041.png
#   inflating: Data/Covid/15941.png
#   inflating: Data/Covid/17501.png
#   inflating: Data/Covid/14901.png
#   inflating: Data/Covid/13741.png
#   inflating: Data/Covid/18051.png
#   inflating: Data/Covid/17916.png
#   inflating: Data/Covid/18826.png
#   inflating: Data/Covid/12576.png
#   inflating: Data/Covid/12541.png
#   inflating: Data/Covid/15721.png
#   inflating: Data/Covid/11716.png
#   inflating: Data/Covid/18841.png
#   inflating: Data/Covid/15026.png
#   inflating: Data/Covid/16801.png
#   inflating: Data/Covid/10671.png
#   inflating: Data/Covid/12001.png
#   inflating: Data/Covid/14781.png
#   inflating: Data/Covid/16926.png
#   inflating: Data/Covid/18871.png
#   inflating: Data/Covid/18681.png
#   inflating: Data/Covid/16991.png
#   inflating: Data/Covid/13526.png
#   inflating: Data/Covid/13341.png
#   inflating: Data/Covid/18561.png
#   inflating: Data/Covid/12506.png
#   inflating: Data/Covid/12696.png
#   inflating: Data/Covid/17026.png
#   inflating: Data/Covid/11936.png
#   inflating: Data/Covid/16966.png
#   inflating: Data/Covid/10336.png
#   inflating: Data/Covid/11096.png
#   inflating: Data/Covid/13306.png
#   inflating: Data/Covid/11761.png
#   inflating: Data/Covid/12926.png
#   inflating: Data/Covid/12671.png
#   inflating: Data/Covid/15286.png
#   inflating: Data/Covid/Covid/.DS_Store
#   inflating: Data/Covid/Covid/Patient (12)/Covid - Shortcut.lnk
#   inflating: Data/Covid/10038.png
#   inflating: Data/Covid/10053.png
#   inflating: Data/Covid/10065.png
#   inflating: Data/Covid/10070.png
#   inflating: Data/Covid/10089.png
#   inflating: Data/Covid/10099.png
#   inflating: Data/Covid/10109.png
#   inflating: Data/Covid/10127.png
#   inflating: Data/Covid/10140.png
#   inflating: Data/Covid/10148.png
#   inflating: Data/Covid/10160.png
#   inflating: Data/Covid/10170.png
#   inflating: Data/Covid/10177.png
#   inflating: Data/Covid/10199.png
#   inflating: Data/Covid/10224.png
#   inflating: Data/Covid/10244.png
#   inflating: Data/Covid/10253.png
#   inflating: Data/Covid/10265.png
#   inflating: Data/Covid/10289.png
#   inflating: Data/Covid/10298.png
#   inflating: Data/Covid/10319.png
#   inflating: Data/Covid/10322.png
#   inflating: Data/Covid/10325.png
#   inflating: Data/Covid/10335.png
#   inflating: Data/Covid/10340.png
#   inflating: Data/Covid/10343.png
#   inflating: Data/Covid/10347.png
#   inflating: Data/Covid/10360.png
#   inflating: Data/Covid/10364.png
#   inflating: Data/Covid/10367.png
#   inflating: Data/Covid/10374.png
#   inflating: Data/Covid/10380.png
#   inflating: Data/Covid/10438.png
#   inflating: Data/Covid/10440.png
#   inflating: Data/Covid/10455.png
#   inflating: Data/Covid/10457.png
#   inflating: Data/Covid/10479.png
#   inflating: Data/Covid/10495.png
#   inflating: Data/Covid/10507.png
#   inflating: Data/Covid/10515.png
#   inflating: Data/Covid/10538.png
#   inflating: Data/Covid/10560.png
#   inflating: Data/Covid/10569.png
#   inflating: Data/Covid/10570.png
#   inflating: Data/Covid/10573.png
#   inflating: Data/Covid/10589.png
#   inflating: Data/Covid/10599.png
#   inflating: Data/Covid/10609.png
#   inflating: Data/Covid/10649.png
#   inflating: Data/Covid/10659.png
#   inflating: Data/Covid/10672.png
#   inflating: Data/Covid/10690.png
#   inflating: Data/Covid/10692.png
#   inflating: Data/Covid/10695.png
#   inflating: Data/Covid/10700.png
#   inflating: Data/Covid/10707.png
#   inflating: Data/Covid/10733.png
#   inflating: Data/Covid/10747.png
#   inflating: Data/Covid/10755.png
#   inflating: Data/Covid/10758.png
#   inflating: Data/Covid/10777.png
#   inflating: Data/Covid/10799.png
#   inflating: Data/Covid/10803.png
#   inflating: Data/Covid/10825.png
#   inflating: Data/Covid/10833.png
#   inflating: Data/Covid/10840.png
#   inflating: Data/Covid/10853.png
#   inflating: Data/Covid/10865.png
#   inflating: Data/Covid/10868.png
#   inflating: Data/Covid/10873.png
#   inflating: Data/Covid/10878.png
#   inflating: Data/Covid/10879.png
#   inflating: Data/Covid/10889.png
#   inflating: Data/Covid/10908.png
#   inflating: Data/Covid/10915.png
#   inflating: Data/Covid/10932.png
#   inflating: Data/Covid/10935.png
#   inflating: Data/Covid/10964.png
#   inflating: Data/Covid/10977.png
#   inflating: Data/Covid/11010.png
#   inflating: Data/Covid/11027.png
#   inflating: Data/Covid/11033.png
#   inflating: Data/Covid/11037.png
#   inflating: Data/Covid/11065.png
#   inflating: Data/Covid/11083.png
#   inflating: Data/Covid/11098.png
#   inflating: Data/Covid/11105.png
#   inflating: Data/Covid/11153.png
#   inflating: Data/Covid/11157.png
#   inflating: Data/Covid/11180.png
#   inflating: Data/Covid/11183.png
#   inflating: Data/Covid/11190.png
#   inflating: Data/Covid/11200.png
#   inflating: Data/Covid/11213.png
#   inflating: Data/Covid/11228.png
#   inflating: Data/Covid/11245.png
#   inflating: Data/Covid/11247.png
#   inflating: Data/Covid/11254.png
#   inflating: Data/Covid/11269.png
#   inflating: Data/Covid/11298.png
#   inflating: Data/Covid/11320.png
#   inflating: Data/Covid/11322.png
#   inflating: Data/Covid/11354.png
#   inflating: Data/Covid/11374.png
#   inflating: Data/Covid/11432.png
#   inflating: Data/Covid/11443.png
#   inflating: Data/Covid/11454.png
#   inflating: Data/Covid/11474.png
#   inflating: Data/Covid/11489.png
#   inflating: Data/Covid/11505.png
#   inflating: Data/Covid/11513.png
#   inflating: Data/Covid/11527.png
#   inflating: Data/Covid/11529.png
#   inflating: Data/Covid/11537.png
#   inflating: Data/Covid/11539.png
#   inflating: Data/Covid/11554.png
#   inflating: Data/Covid/11558.png
#   inflating: Data/Covid/11585.png
#   inflating: Data/Covid/11587.png
#   inflating: Data/Covid/11590.png
#   inflating: Data/Covid/11593.png
#   inflating: Data/Covid/11595.png
#   inflating: Data/Covid/11602.png
#   inflating: Data/Covid/11612.png
#   inflating: Data/Covid/11624.png
#   inflating: Data/Covid/11629.png
#   inflating: Data/Covid/11630.png
#   inflating: Data/Covid/11648.png
#   inflating: Data/Covid/11658.png
#   inflating: Data/Covid/11668.png
#   inflating: Data/Covid/11670.png
#   inflating: Data/Covid/11685.png
#   inflating: Data/Covid/11687.png
#   inflating: Data/Covid/11704.png
#   inflating: Data/Covid/11719.png
#   inflating: Data/Covid/11722.png
#   inflating: Data/Covid/11724.png
#   inflating: Data/Covid/11732.png
#   inflating: Data/Covid/11734.png
#   inflating: Data/Covid/11735.png
#   inflating: Data/Covid/11750.png
#   inflating: Data/Covid/11753.png
#   inflating: Data/Covid/11755.png
#   inflating: Data/Covid/11767.png
#   inflating: Data/Covid/11805.png
#   inflating: Data/Covid/11810.png
#   inflating: Data/Covid/11822.png
#   inflating: Data/Covid/11832.png
#   inflating: Data/Covid/11838.png
#   inflating: Data/Covid/11839.png
#   inflating: Data/Covid/11849.png
#   inflating: Data/Covid/11850.png
#   inflating: Data/Covid/11855.png
#   inflating: Data/Covid/11864.png
#   inflating: Data/Covid/11865.png
#   inflating: Data/Covid/11878.png
#   inflating: Data/Covid/11945.png
#   inflating: Data/Covid/11974.png
#   inflating: Data/Covid/11998.png
#   inflating: Data/Covid/12012.png
#   inflating: Data/Covid/12013.png
#   inflating: Data/Covid/12017.png
#   inflating: Data/Covid/12022.png
#   inflating: Data/Covid/12024.png
#   inflating: Data/Covid/12039.png
#   inflating: Data/Covid/12054.png
#   inflating: Data/Covid/12064.png
#   inflating: Data/Covid/12065.png
#   inflating: Data/Covid/12079.png
#   inflating: Data/Covid/12094.png
#   inflating: Data/Covid/12100.png
#   inflating: Data/Covid/12119.png
#   inflating: Data/Covid/12138.png
#   inflating: Data/Covid/12140.png
#   inflating: Data/Covid/12145.png
#   inflating: Data/Covid/12179.png
#   inflating: Data/Covid/12180.png
#   inflating: Data/Covid/12192.png
#   inflating: Data/Covid/12203.png
#   inflating: Data/Covid/12213.png
#   inflating: Data/Covid/12218.png
#   inflating: Data/Covid/12222.png
#   inflating: Data/Covid/12254.png
#   inflating: Data/Covid/12269.png
#   inflating: Data/Covid/12287.png
#   inflating: Data/Covid/12294.png
#   inflating: Data/Covid/12317.png
#   inflating: Data/Covid/12332.png
#   inflating: Data/Covid/12335.png
#   inflating: Data/Covid/12340.png
#   inflating: Data/Covid/12363.png
#   inflating: Data/Covid/12379.png
#   inflating: Data/Covid/12387.png
#   inflating: Data/Covid/12390.png
#   inflating: Data/Covid/12393.png
#   inflating: Data/Covid/12413.png
#   inflating: Data/Covid/12427.png
#   inflating: Data/Covid/12428.png
#   inflating: Data/Covid/12432.png
#   inflating: Data/Covid/12434.png
#   inflating: Data/Covid/12439.png
#   inflating: Data/Covid/12448.png
#   inflating: Data/Covid/12452.png
#   inflating: Data/Covid/12453.png
#   inflating: Data/Covid/12459.png
#   inflating: Data/Covid/12464.png
#   inflating: Data/Covid/12465.png
#   inflating: Data/Covid/12472.png
#   inflating: Data/Covid/12477.png
#   inflating: Data/Covid/12479.png
#   inflating: Data/Covid/12480.png
#   inflating: Data/Covid/12485.png
#   inflating: Data/Covid/12494.png
#   inflating: Data/Covid/12504.png
#   inflating: Data/Covid/12543.png
#   inflating: Data/Covid/12563.png
#   inflating: Data/Covid/12569.png
#   inflating: Data/Covid/12573.png
#   inflating: Data/Covid/12574.png
#   inflating: Data/Covid/12587.png
#   inflating: Data/Covid/12589.png
#   inflating: Data/Covid/12599.png
#   inflating: Data/Covid/12600.png
#   inflating: Data/Covid/12625.png
#   inflating: Data/Covid/12642.png
#   inflating: Data/Covid/12659.png
#   inflating: Data/Covid/12670.png
#   inflating: Data/Covid/12673.png
#   inflating: Data/Covid/12677.png
#   inflating: Data/Covid/12682.png
#   inflating: Data/Covid/12693.png
#   inflating: Data/Covid/12702.png
#   inflating: Data/Covid/12713.png
#   inflating: Data/Covid/12727.png
#   inflating: Data/Covid/12729.png
#   inflating: Data/Covid/12770.png
#   inflating: Data/Covid/12772.png
#   inflating: Data/Covid/12785.png
#   inflating: Data/Covid/12820.png
#   inflating: Data/Covid/12824.png
#   inflating: Data/Covid/12827.png
#   inflating: Data/Covid/12842.png
#   inflating: Data/Covid/12848.png
#   inflating: Data/Covid/12870.png
#   inflating: Data/Covid/12873.png
#   inflating: Data/Covid/12878.png
#   inflating: Data/Covid/12880.png
#   inflating: Data/Covid/12888.png
#   inflating: Data/Covid/12889.png
#   inflating: Data/Covid/12905.png
#   inflating: Data/Covid/12910.png
#   inflating: Data/Covid/12914.png
#   inflating: Data/Covid/12938.png
#   inflating: Data/Covid/12955.png
#   inflating: Data/Covid/12958.png
#   inflating: Data/Covid/12960.png
#   inflating: Data/Covid/12963.png
#   inflating: Data/Covid/12990.png
#   inflating: Data/Covid/13009.png
#   inflating: Data/Covid/13037.png
#   inflating: Data/Covid/13040.png
#   inflating: Data/Covid/13045.png
#   inflating: Data/Covid/13050.png
#   inflating: Data/Covid/13060.png
#   inflating: Data/Covid/13083.png
#   inflating: Data/Covid/13109.png
#   inflating: Data/Covid/13132.png
#   inflating: Data/Covid/13143.png
#   inflating: Data/Covid/13148.png
#   inflating: Data/Covid/13165.png
#   inflating: Data/Covid/13168.png
#   inflating: Data/Covid/13169.png
#   inflating: Data/Covid/13170.png
#   inflating: Data/Covid/13172.png
#   inflating: Data/Covid/13179.png
#   inflating: Data/Covid/13183.png
#   inflating: Data/Covid/13190.png
#   inflating: Data/Covid/13194.png
#   inflating: Data/Covid/13204.png
#   inflating: Data/Covid/13209.png
#   inflating: Data/Covid/13214.png
#   inflating: Data/Covid/13219.png
#   inflating: Data/Covid/13238.png
#   inflating: Data/Covid/13248.png
#   inflating: Data/Covid/13259.png
#   inflating: Data/Covid/13267.png
#   inflating: Data/Covid/13268.png
#   inflating: Data/Covid/13270.png
#   inflating: Data/Covid/13274.png
#   inflating: Data/Covid/13287.png
#   inflating: Data/Covid/13290.png
#   inflating: Data/Covid/13298.png
#   inflating: Data/Covid/13299.png
#   inflating: Data/Covid/13302.png
#   inflating: Data/Covid/13333.png
#   inflating: Data/Covid/13338.png
#   inflating: Data/Covid/13339.png
#   inflating: Data/Covid/13342.png
#   inflating: Data/Covid/13365.png
#   inflating: Data/Covid/13367.png
#   inflating: Data/Covid/13375.png
#   inflating: Data/Covid/13404.png
#   inflating: Data/Covid/13419.png
#   inflating: Data/Covid/13433.png
#   inflating: Data/Covid/13483.png
#   inflating: Data/Covid/13490.png
#   inflating: Data/Covid/13519.png
#   inflating: Data/Covid/13522.png
#   inflating: Data/Covid/13545.png
#   inflating: Data/Covid/13564.png
#   inflating: Data/Covid/13572.png
#   inflating: Data/Covid/13574.png
#   inflating: Data/Covid/13575.png
#   inflating: Data/Covid/13597.png
#   inflating: Data/Covid/13610.png
#   inflating: Data/Covid/13614.png
#   inflating: Data/Covid/13619.png
#   inflating: Data/Covid/13620.png
#   inflating: Data/Covid/13622.png
#   inflating: Data/Covid/13647.png
#   inflating: Data/Covid/13660.png
#   inflating: Data/Covid/13685.png
#   inflating: Data/Covid/13714.png
#   inflating: Data/Covid/13723.png
#   inflating: Data/Covid/13735.png
#   inflating: Data/Covid/13739.png
#   inflating: Data/Covid/13748.png
#   inflating: Data/Covid/13770.png
#   inflating: Data/Covid/13774.png
#   inflating: Data/Covid/13782.png
#   inflating: Data/Covid/13797.png
#   inflating: Data/Covid/13803.png
#   inflating: Data/Covid/13804.png
#   inflating: Data/Covid/13808.png
#   inflating: Data/Covid/13823.png
#   inflating: Data/Covid/13829.png
#   inflating: Data/Covid/13833.png
#   inflating: Data/Covid/13843.png
#   inflating: Data/Covid/13852.png
#   inflating: Data/Covid/13872.png
#   inflating: Data/Covid/13873.png
#   inflating: Data/Covid/13883.png
#   inflating: Data/Covid/13898.png
#   inflating: Data/Covid/13902.png
#   inflating: Data/Covid/13910.png
#   inflating: Data/Covid/13934.png
#   inflating: Data/Covid/13969.png
#   inflating: Data/Covid/13985.png
#   inflating: Data/Covid/14008.png
#   inflating: Data/Covid/14013.png
#   inflating: Data/Covid/14027.png
#   inflating: Data/Covid/14040.png
#   inflating: Data/Covid/14060.png
#   inflating: Data/Covid/14063.png
#   inflating: Data/Covid/14064.png
#   inflating: Data/Covid/14075.png
#   inflating: Data/Covid/14102.png
#   inflating: Data/Covid/14105.png
#   inflating: Data/Covid/14114.png
#   inflating: Data/Covid/14119.png
#   inflating: Data/Covid/14133.png
#   inflating: Data/Covid/14144.png
#   inflating: Data/Covid/14163.png
#   inflating: Data/Covid/14173.png
#   inflating: Data/Covid/14179.png
#   inflating: Data/Covid/14184.png
#   inflating: Data/Covid/14197.png
#   inflating: Data/Covid/14198.png
#   inflating: Data/Covid/14213.png
#   inflating: Data/Covid/14218.png
#   inflating: Data/Covid/14223.png
#   inflating: Data/Covid/14225.png
#   inflating: Data/Covid/14263.png
#   inflating: Data/Covid/14277.png
#   inflating: Data/Covid/14279.png
#   inflating: Data/Covid/14337.png
#   inflating: Data/Covid/14339.png
#   inflating: Data/Covid/14372.png
#   inflating: Data/Covid/14394.png
#   inflating: Data/Covid/14410.png
#   inflating: Data/Covid/14413.png
#   inflating: Data/Covid/14420.png
#   inflating: Data/Covid/14439.png
#   inflating: Data/Covid/14442.png
#   inflating: Data/Covid/14448.png
#   inflating: Data/Covid/14468.png
#   inflating: Data/Covid/14480.png
#   inflating: Data/Covid/14494.png
#   inflating: Data/Covid/14500.png
#   inflating: Data/Covid/14514.png
#   inflating: Data/Covid/14523.png
#   inflating: Data/Covid/14524.png
#   inflating: Data/Covid/14528.png
#   inflating: Data/Covid/14530.png
#   inflating: Data/Covid/14567.png
#   inflating: Data/Covid/14570.png
#   inflating: Data/Covid/14579.png
#   inflating: Data/Covid/14588.png
#   inflating: Data/Covid/14595.png
#   inflating: Data/Covid/14604.png
#   inflating: Data/Covid/14617.png
#   inflating: Data/Covid/14629.png
#   inflating: Data/Covid/14630.png
#   inflating: Data/Covid/14638.png
#   inflating: Data/Covid/14655.png
#   inflating: Data/Covid/14677.png
#   inflating: Data/Covid/14699.png
#   inflating: Data/Covid/14703.png
#   inflating: Data/Covid/14704.png
#   inflating: Data/Covid/14705.png
#   inflating: Data/Covid/14710.png
#   inflating: Data/Covid/14718.png
#   inflating: Data/Covid/14748.png
#   inflating: Data/Covid/14752.png
#   inflating: Data/Covid/14755.png
#   inflating: Data/Covid/14765.png
#   inflating: Data/Covid/14774.png
#   inflating: Data/Covid/14784.png
#   inflating: Data/Covid/14802.png
#   inflating: Data/Covid/14804.png
#   inflating: Data/Covid/14818.png
#   inflating: Data/Covid/14840.png
#   inflating: Data/Covid/14858.png
#   inflating: Data/Covid/14888.png
#   inflating: Data/Covid/14898.png
#   inflating: Data/Covid/14905.png
#   inflating: Data/Covid/14912.png
#   inflating: Data/Covid/14922.png
#   inflating: Data/Covid/14932.png
#   inflating: Data/Covid/14937.png
#   inflating: Data/Covid/14972.png
#   inflating: Data/Covid/14983.png
#   inflating: Data/Covid/14987.png
#   inflating: Data/Covid/14989.png
#   inflating: Data/Covid/15002.png
#   inflating: Data/Covid/15030.png
#   inflating: Data/Covid/15032.png
#   inflating: Data/Covid/15033.png
#   inflating: Data/Covid/15035.png
#   inflating: Data/Covid/15040.png
#   inflating: Data/Covid/15053.png
#   inflating: Data/Covid/15057.png
#   inflating: Data/Covid/15085.png
#   inflating: Data/Covid/15087.png
#   inflating: Data/Covid/15090.png
#   inflating: Data/Covid/15092.png
#   inflating: Data/Covid/15122.png
#   inflating: Data/Covid/15144.png
#   inflating: Data/Covid/15147.png
#   inflating: Data/Covid/15154.png
#   inflating: Data/Covid/15158.png
#   inflating: Data/Covid/15169.png
#   inflating: Data/Covid/15174.png
#   inflating: Data/Covid/15189.png
#   inflating: Data/Covid/15203.png
#   inflating: Data/Covid/15205.png
#   inflating: Data/Covid/15237.png
#   inflating: Data/Covid/15250.png
#   inflating: Data/Covid/15254.png
#   inflating: Data/Covid/15259.png
#   inflating: Data/Covid/15269.png
#   inflating: Data/Covid/15288.png
#   inflating: Data/Covid/15292.png
#   inflating: Data/Covid/15298.png
#   inflating: Data/Covid/15312.png
#   inflating: Data/Covid/15327.png
#   inflating: Data/Covid/15330.png
#   inflating: Data/Covid/15335.png
#   inflating: Data/Covid/15337.png
#   inflating: Data/Covid/15350.png
#   inflating: Data/Covid/15359.png
#   inflating: Data/Covid/15367.png
#   inflating: Data/Covid/15369.png
#   inflating: Data/Covid/15378.png
#   inflating: Data/Covid/15379.png
#   inflating: Data/Covid/15388.png
#   inflating: Data/Covid/15392.png
#   inflating: Data/Covid/15407.png
#   inflating: Data/Covid/15442.png
#   inflating: Data/Covid/15453.png
#   inflating: Data/Covid/15472.png
#   inflating: Data/Covid/15483.png
#   inflating: Data/Covid/15500.png
#   inflating: Data/Covid/15509.png
#   inflating: Data/Covid/15525.png
#   inflating: Data/Covid/15527.png
#   inflating: Data/Covid/15528.png
#   inflating: Data/Covid/15530.png
#   inflating: Data/Covid/15553.png
#   inflating: Data/Covid/15554.png
#   inflating: Data/Covid/15568.png
#   inflating: Data/Covid/15569.png
#   inflating: Data/Covid/15585.png
#   inflating: Data/Covid/15592.png
#   inflating: Data/Covid/15599.png
#   inflating: Data/Covid/15624.png
#   inflating: Data/Covid/15644.png
#   inflating: Data/Covid/15645.png
#   inflating: Data/Covid/15680.png
#   inflating: Data/Covid/15682.png
#   inflating: Data/Covid/15689.png
#   inflating: Data/Covid/15717.png
#   inflating: Data/Covid/15727.png
#   inflating: Data/Covid/15742.png
#   inflating: Data/Covid/15745.png
#   inflating: Data/Covid/15748.png
#   inflating: Data/Covid/15812.png
#   inflating: Data/Covid/15818.png
#   inflating: Data/Covid/15828.png
#   inflating: Data/Covid/15842.png
#   inflating: Data/Covid/15862.png
#   inflating: Data/Covid/15864.png
#   inflating: Data/Covid/15873.png
#   inflating: Data/Covid/15893.png
#   inflating: Data/Covid/15919.png
#   inflating: Data/Covid/15927.png
#   inflating: Data/Covid/15939.png
#   inflating: Data/Covid/15964.png
#   inflating: Data/Covid/15972.png
#   inflating: Data/Covid/15992.png
#   inflating: Data/Covid/16000.png
#   inflating: Data/Covid/16003.png
#   inflating: Data/Covid/16013.png
#   inflating: Data/Covid/16037.png
#   inflating: Data/Covid/16049.png
#   inflating: Data/Covid/16059.png
#   inflating: Data/Covid/16090.png
#   inflating: Data/Covid/16102.png
#   inflating: Data/Covid/16103.png
#   inflating: Data/Covid/16107.png
#   inflating: Data/Covid/16110.png
#   inflating: Data/Covid/16124.png
#   inflating: Data/Covid/16135.png
#   inflating: Data/Covid/16139.png
#   inflating: Data/Covid/16144.png
#   inflating: Data/Covid/16154.png
#   inflating: Data/Covid/16164.png
#   inflating: Data/Covid/16167.png
#   inflating: Data/Covid/16217.png
#   inflating: Data/Covid/16218.png
#   inflating: Data/Covid/16227.png
#   inflating: Data/Covid/16229.png
#   inflating: Data/Covid/16242.png
#   inflating: Data/Covid/16274.png
#   inflating: Data/Covid/16287.png
#   inflating: Data/Covid/16289.png
#   inflating: Data/Covid/16293.png
#   inflating: Data/Covid/16302.png
#   inflating: Data/Covid/16305.png
#   inflating: Data/Covid/16307.png
#   inflating: Data/Covid/16320.png
#   inflating: Data/Covid/16323.png
#   inflating: Data/Covid/16340.png
#   inflating: Data/Covid/16363.png
#   inflating: Data/Covid/16364.png
#   inflating: Data/Covid/16378.png
#   inflating: Data/Covid/16388.png
#   inflating: Data/Covid/16409.png
#   inflating: Data/Covid/16427.png
#   inflating: Data/Covid/16429.png
#   inflating: Data/Covid/16430.png
#   inflating: Data/Covid/16452.png
#   inflating: Data/Covid/16460.png
#   inflating: Data/Covid/16472.png
#   inflating: Data/Covid/16482.png
#   inflating: Data/Covid/16493.png
#   inflating: Data/Covid/16522.png
#   inflating: Data/Covid/16533.png
#   inflating: Data/Covid/16538.png
#   inflating: Data/Covid/16544.png
#   inflating: Data/Covid/16548.png
#   inflating: Data/Covid/16553.png
#   inflating: Data/Covid/16554.png
#   inflating: Data/Covid/16563.png
#   inflating: Data/Covid/16578.png
#   inflating: Data/Covid/16584.png
#   inflating: Data/Covid/16587.png
#   inflating: Data/Covid/16588.png
#   inflating: Data/Covid/16603.png
#   inflating: Data/Covid/16608.png
#   inflating: Data/Covid/16620.png
#   inflating: Data/Covid/16645.png
#   inflating: Data/Covid/16648.png
#   inflating: Data/Covid/16650.png
#   inflating: Data/Covid/16657.png
#   inflating: Data/Covid/16664.png
#   inflating: Data/Covid/16693.png
#   inflating: Data/Covid/16695.png
#   inflating: Data/Covid/16697.png
#   inflating: Data/Covid/16712.png
#   inflating: Data/Covid/16713.png
#   inflating: Data/Covid/16714.png
#   inflating: Data/Covid/16735.png
#   inflating: Data/Covid/16738.png
#   inflating: Data/Covid/16745.png
#   inflating: Data/Covid/16760.png
#   inflating: Data/Covid/16774.png
#   inflating: Data/Covid/16775.png
#   inflating: Data/Covid/16785.png
#   inflating: Data/Covid/16790.png
#   inflating: Data/Covid/16803.png
#   inflating: Data/Covid/16818.png
#   inflating: Data/Covid/16832.png
#   inflating: Data/Covid/16833.png
#   inflating: Data/Covid/16835.png
#   inflating: Data/Covid/16853.png
#   inflating: Data/Covid/16862.png
#   inflating: Data/Covid/16880.png
#   inflating: Data/Covid/16909.png
#   inflating: Data/Covid/16929.png
#   inflating: Data/Covid/16942.png
#   inflating: Data/Covid/16962.png
#   inflating: Data/Covid/16995.png
#   inflating: Data/Covid/17012.png
#   inflating: Data/Covid/17030.png
#   inflating: Data/Covid/17054.png
#   inflating: Data/Covid/17070.png
#   inflating: Data/Covid/17074.png
#   inflating: Data/Covid/17084.png
#   inflating: Data/Covid/17090.png
#   inflating: Data/Covid/17092.png
#   inflating: Data/Covid/17120.png
#   inflating: Data/Covid/17122.png
#   inflating: Data/Covid/17138.png
#   inflating: Data/Covid/17153.png
#   inflating: Data/Covid/17162.png
#   inflating: Data/Covid/17173.png
#   inflating: Data/Covid/17179.png
#   inflating: Data/Covid/17183.png
#   inflating: Data/Covid/17190.png
#   inflating: Data/Covid/17245.png
#   inflating: Data/Covid/17260.png
#   inflating: Data/Covid/17277.png
#   inflating: Data/Covid/17278.png
#   inflating: Data/Covid/17285.png
#   inflating: Data/Covid/17288.png
#   inflating: Data/Covid/17308.png
#   inflating: Data/Covid/17314.png
#   inflating: Data/Covid/17318.png
#   inflating: Data/Covid/17320.png
#   inflating: Data/Covid/17332.png
#   inflating: Data/Covid/17337.png
#   inflating: Data/Covid/17355.png
#   inflating: Data/Covid/17365.png
#   inflating: Data/Covid/17375.png
#   inflating: Data/Covid/17392.png
#   inflating: Data/Covid/17408.png
#   inflating: Data/Covid/17437.png
#   inflating: Data/Covid/17485.png
#   inflating: Data/Covid/17489.png
#   inflating: Data/Covid/17493.png
#   inflating: Data/Covid/17499.png
#   inflating: Data/Covid/17503.png
#   inflating: Data/Covid/17512.png
#   inflating: Data/Covid/17520.png
#   inflating: Data/Covid/17524.png
#   inflating: Data/Covid/17538.png
#   inflating: Data/Covid/17544.png
#   inflating: Data/Covid/17565.png
#   inflating: Data/Covid/17600.png
#   inflating: Data/Covid/17628.png
#   inflating: Data/Covid/17644.png
#   inflating: Data/Covid/17653.png
#   inflating: Data/Covid/17654.png
#   inflating: Data/Covid/17673.png
#   inflating: Data/Covid/17675.png
#   inflating: Data/Covid/17698.png
#   inflating: Data/Covid/17699.png
#   inflating: Data/Covid/17719.png
#   inflating: Data/Covid/17723.png
#   inflating: Data/Covid/17745.png
#   inflating: Data/Covid/17748.png
#   inflating: Data/Covid/17754.png
#   inflating: Data/Covid/17758.png
#   inflating: Data/Covid/17759.png
#   inflating: Data/Covid/17795.png
#   inflating: Data/Covid/17808.png
#   inflating: Data/Covid/17813.png
#   inflating: Data/Covid/17824.png
#   inflating: Data/Covid/17873.png
#   inflating: Data/Covid/17894.png
#   inflating: Data/Covid/17899.png
#   inflating: Data/Covid/17913.png
#   inflating: Data/Covid/17915.png
#   inflating: Data/Covid/17928.png
#   inflating: Data/Covid/17933.png
#   inflating: Data/Covid/17934.png
#   inflating: Data/Covid/17947.png
#   inflating: Data/Covid/17950.png
#   inflating: Data/Covid/17953.png
#   inflating: Data/Covid/17957.png
#   inflating: Data/Covid/17959.png
#   inflating: Data/Covid/17963.png
#   inflating: Data/Covid/18015.png
#   inflating: Data/Covid/18018.png
#   inflating: Data/Covid/18028.png
#   inflating: Data/Covid/18032.png
#   inflating: Data/Covid/18035.png
#   inflating: Data/Covid/18049.png
#   inflating: Data/Covid/18057.png
#   inflating: Data/Covid/18060.png
#   inflating: Data/Covid/18103.png
#   inflating: Data/Covid/18104.png
#   inflating: Data/Covid/18109.png
#   inflating: Data/Covid/18123.png
#   inflating: Data/Covid/18130.png
#   inflating: Data/Covid/18142.png
#   inflating: Data/Covid/18145.png
#   inflating: Data/Covid/18150.png
#   inflating: Data/Covid/18154.png
#   inflating: Data/Covid/18165.png
#   inflating: Data/Covid/18180.png
#   inflating: Data/Covid/18212.png
#   inflating: Data/Covid/18217.png
#   inflating: Data/Covid/18219.png
#   inflating: Data/Covid/18237.png
#   inflating: Data/Covid/18265.png
#   inflating: Data/Covid/18273.png
#   inflating: Data/Covid/18284.png
#   inflating: Data/Covid/18285.png
#   inflating: Data/Covid/18298.png
#   inflating: Data/Covid/18314.png
#   inflating: Data/Covid/18322.png
#   inflating: Data/Covid/18327.png
#   inflating: Data/Covid/18330.png
#   inflating: Data/Covid/18337.png
#   inflating: Data/Covid/18385.png
#   inflating: Data/Covid/18388.png
#   inflating: Data/Covid/18397.png
#   inflating: Data/Covid/18399.png
#   inflating: Data/Covid/18412.png
#   inflating: Data/Covid/18413.png
#   inflating: Data/Covid/18414.png
#   inflating: Data/Covid/18422.png
#   inflating: Data/Covid/18438.png
#   inflating: Data/Covid/18442.png
#   inflating: Data/Covid/18473.png
#   inflating: Data/Covid/18493.png
#   inflating: Data/Covid/18507.png
#   inflating: Data/Covid/18514.png
#   inflating: Data/Covid/18518.png
#   inflating: Data/Covid/18525.png
#   inflating: Data/Covid/18533.png
#   inflating: Data/Covid/18534.png
#   inflating: Data/Covid/18542.png
#   inflating: Data/Covid/18543.png
#   inflating: Data/Covid/18579.png
#   inflating: Data/Covid/18585.png
#   inflating: Data/Covid/18615.png
#   inflating: Data/Covid/18617.png
#   inflating: Data/Covid/18623.png
#   inflating: Data/Covid/18632.png
#   inflating: Data/Covid/18653.png
#   inflating: Data/Covid/18673.png
#   inflating: Data/Covid/18687.png
#   inflating: Data/Covid/18688.png
#   inflating: Data/Covid/18699.png
#   inflating: Data/Covid/18705.png
#   inflating: Data/Covid/18712.png
#   inflating: Data/Covid/18725.png
#   inflating: Data/Covid/18729.png
#   inflating: Data/Covid/18739.png
#   inflating: Data/Covid/18757.png
#   inflating: Data/Covid/18759.png
#   inflating: Data/Covid/18768.png
#   inflating: Data/Covid/18773.png
#   inflating: Data/Covid/18792.png
#   inflating: Data/Covid/18828.png
#   inflating: Data/Covid/18832.png
#   inflating: Data/Covid/18852.png
#   inflating: Data/Covid/18853.png
#   inflating: Data/Covid/18893.png
#   inflating: Data/Covid/18900.png
#   inflating: Data/Covid/18903.png
#   inflating: Data/Covid/18910.png
#   inflating: Data/Covid/18933.png
#   inflating: Data/Covid/18955.png
#   inflating: Data/Covid/18957.png
#   inflating: Data/Covid/18967.png
#   inflating: Data/Covid/18974.png
#   inflating: Data/Covid/18977.png
#   inflating: Data/Covid/18985.png
#   inflating: Data/Covid/18989.png
#   inflating: Data/Covid/18995.png
#   inflating: Data/Covid/19012.png
#   inflating: Data/Covid/16506.png
#   inflating: Data/Covid/11389.png
#   inflating: Data/Covid/11604.png
#   inflating: Data/Covid/11674.png
#   inflating: Data/Covid/11792.png
#   inflating: Data/Covid/12575.png
#   inflating: Data/Covid/14188.png
#   inflating: Data/Covid/14359.png
#   inflating: Data/Covid/16758.png
#   inflating: Data/Covid/18517.png
#   inflating: Data/Covid/18563.png
#   inflating: Data/Healthy/7.png
#   inflating: Data/Healthy/11.png
#   inflating: Data/Healthy/13.png
#   inflating: Data/Healthy/18.png
#   inflating: Data/Healthy/19.png
#   inflating: Data/Healthy/23.png
#   inflating: Data/Healthy/24.png
#   inflating: Data/Healthy/36.png
#   inflating: Data/Healthy/37.png
#   inflating: Data/Healthy/43.png
#   inflating: Data/Healthy/52.png
#   inflating: Data/Healthy/59.png
#   inflating: Data/Healthy/70.png
#   inflating: Data/Healthy/72.png
#   inflating: Data/Healthy/75.png
#   inflating: Data/Healthy/77.png
#   inflating: Data/Healthy/82.png
#   inflating: Data/Healthy/83.png
#   inflating: Data/Healthy/84.png
#   inflating: Data/Healthy/87.png
#   inflating: Data/Healthy/92.png
#   inflating: Data/Healthy/93.png
#   inflating: Data/Healthy/103.png
#   inflating: Data/Healthy/105.png
#   inflating: Data/Healthy/107.png
#   inflating: Data/Healthy/121.png
#   inflating: Data/Healthy/122.png
#   inflating: Data/Healthy/127.png
#   inflating: Data/Healthy/130.png
#   inflating: Data/Healthy/133.png
#   inflating: Data/Healthy/136.png
#   inflating: Data/Healthy/139.png
#   inflating: Data/Healthy/141.png
#   inflating: Data/Healthy/143.png
#   inflating: Data/Healthy/144.png
#   inflating: Data/Healthy/150.png
#   inflating: Data/Healthy/151.png
#   inflating: Data/Healthy/153.png
#   inflating: Data/Healthy/155.png
#   inflating: Data/Healthy/161.png
#   inflating: Data/Healthy/162.png
#   inflating: Data/Healthy/167.png
#   inflating: Data/Healthy/172.png
#   inflating: Data/Healthy/174.png
#   inflating: Data/Healthy/180.png
#   inflating: Data/Healthy/182.png
#   inflating: Data/Healthy/193.png
# ...
#   inflating: Data/Healthy/1450.png
#   inflating: Data/Healthy/1469.png
#   inflating: Data/Healthy/1472.png
#   inflating: Data/Healthy/1479.png
#   inflating: Data/Healthy/1489.png
#   inflating: Data/Healthy/1494.png
#   inflating: Data/Healthy/1495.png
#   inflating: Data/Healthy/1498.png
#   inflating: Data/Healthy/1507.png
#   inflating: Data/Healthy/1509.png
#   inflating: Data/Healthy/1513.png
#   inflating: Data/Healthy/1514.png
#   inflating: Data/Healthy/1517.png
#   inflating: Data/Healthy/1523.png
#   inflating: Data/Healthy/1532.png
#   inflating: Data/Healthy/1533.png
#   inflating: Data/Healthy/1539.png
#   inflating: Data/Healthy/1545.png
#   inflating: Data/Healthy/1548.png
#   inflating: Data/Healthy/1550.png
#   inflating: Data/Healthy/1573.png
#   inflating: Data/Healthy/1575.png
#   inflating: Data/Healthy/1579.png
#   inflating: Data/Healthy/1593.png
#   inflating: Data/Healthy/1599.png
#   inflating: Data/Healthy/1603.png
#   inflating: Data/Healthy/1609.png
#   inflating: Data/Healthy/1613.png
#   inflating: Data/Healthy/1614.png
#   inflating: Data/Healthy/1620.png
#   inflating: Data/Healthy/1633.png
#   inflating: Data/Healthy/1640.png
#   inflating: Data/Healthy/1647.png
#   inflating: Data/Healthy/1653.png
#   inflating: Data/Healthy/1655.png
#   inflating: Data/Healthy/1677.png
#   inflating: Data/Healthy/1678.png
#   inflating: Data/Healthy/1680.png
#   inflating: Data/Healthy/1683.png
#   inflating: Data/Healthy/1688.png
#   inflating: Data/Healthy/1690.png
#   inflating: Data/Healthy/1702.png
#   inflating: Data/Healthy/1717.png
#   inflating: Data/Healthy/1727.png
#   inflating: Data/Healthy/1733.png
#   inflating: Data/Healthy/1734.png
#   inflating: Data/Healthy/1737.png
#   inflating: Data/Healthy/1738.png
#   inflating: Data/Healthy/1739.png
#   inflating: Data/Healthy/1744.png
#   inflating: Data/Healthy/1762.png
#   inflating: Data/Healthy/1767.png
#   inflating: Data/Healthy/1769.png
#   inflating: Data/Healthy/1785.png
#   inflating: Data/Healthy/1798.png
#   inflating: Data/Healthy/1802.png
#   inflating: Data/Healthy/1819.png
#   inflating: Data/Healthy/1823.png
#   inflating: Data/Healthy/1825.png
#   inflating: Data/Healthy/1833.png
#   inflating: Data/Healthy/1840.png
#   inflating: Data/Healthy/1853.png
#   inflating: Data/Healthy/1855.png
#   inflating: Data/Healthy/1860.png
#   inflating: Data/Healthy/1867.png
#   inflating: Data/Healthy/1869.png
#   inflating: Data/Healthy/1872.png
#   inflating: Data/Healthy/1875.png
#   inflating: Data/Healthy/1884.png
#   inflating: Data/Healthy/1887.png
#   inflating: Data/Healthy/1894.png
#   inflating: Data/Healthy/1897.png
#   inflating: Data/Healthy/1900.png
#   inflating: Data/Healthy/1904.png
#   inflating: Data/Healthy/1915.png
#   inflating: Data/Healthy/1918.png
#   inflating: Data/Healthy/1928.png
#   inflating: Data/Healthy/1935.png
#   inflating: Data/Healthy/1939.png
#   inflating: Data/Healthy/1940.png
#   inflating: Data/Healthy/1942.png
#   inflating: Data/Healthy/1960.png
#   inflating: Data/Healthy/1962.png
#   inflating: Data/Healthy/1963.png
#   inflating: Data/Healthy/1968.png
#   inflating: Data/Healthy/1973.png
#   inflating: Data/Healthy/1975.png
#   inflating: Data/Healthy/1977.png
#   inflating: Data/Healthy/1983.png
#   inflating: Data/Healthy/1985.png
#   inflating: Data/Healthy/1989.png
#   inflating: Data/Healthy/2010.png
#   inflating: Data/Healthy/2012.png
#   inflating: Data/Healthy/2018.png
#   inflating: Data/Healthy/2022.png
#   inflating: Data/Healthy/2023.png
#   inflating: Data/Healthy/2033.png
#   inflating: Data/Healthy/2043.png
#   inflating: Data/Healthy/2045.png
#   inflating: Data/Healthy/2053.png
#   inflating: Data/Healthy/2063.png
#   inflating: Data/Healthy/2065.png
#   inflating: Data/Healthy/2073.png
#   inflating: Data/Healthy/2074.png
#   inflating: Data/Healthy/2088.png
#   inflating: Data/Healthy/2090.png
#   inflating: Data/Healthy/2094.png
#   inflating: Data/Healthy/2100.png
#   inflating: Data/Healthy/2103.png
#   inflating: Data/Healthy/2105.png
#   inflating: Data/Healthy/2108.png
#   inflating: Data/Healthy/2112.png
#   inflating: Data/Healthy/2113.png
#   inflating: Data/Healthy/2122.png
#   inflating: Data/Healthy/2127.png
#   inflating: Data/Healthy/2128.png
#   inflating: Data/Healthy/2135.png
#   inflating: Data/Healthy/2138.png
#   inflating: Data/Healthy/2139.png
#   inflating: Data/Healthy/2160.png
#   inflating: Data/Healthy/2174.png
#   inflating: Data/Healthy/2189.png
#   inflating: Data/Healthy/2198.png
#   inflating: Data/Healthy/2200.png
#   inflating: Data/Healthy/2202.png
#   inflating: Data/Healthy/2212.png
#   inflating: Data/Healthy/2214.png
#   inflating: Data/Healthy/2223.png
#   inflating: Data/Healthy/2224.png
#   inflating: Data/Healthy/2235.png
#   inflating: Data/Healthy/2240.png
#   inflating: Data/Healthy/2245.png
#   inflating: Data/Healthy/2247.png
#   inflating: Data/Healthy/2253.png
#   inflating: Data/Healthy/2259.png
#   inflating: Data/Healthy/2262.png
#   inflating: Data/Healthy/2263.png
#   inflating: Data/Healthy/2265.png
#   inflating: Data/Healthy/2270.png
#   inflating: Data/Healthy/2272.png
#   inflating: Data/Healthy/2277.png
#   inflating: Data/Healthy/2278.png
#   inflating: Data/Healthy/2298.png
#   inflating: Data/Healthy/2299.png
#   inflating: Data/Healthy/2304.png
#   inflating: Data/Healthy/2315.png
#   inflating: Data/Healthy/2318.png
#   inflating: Data/Healthy/2319.png
#   inflating: Data/Healthy/2322.png
#   inflating: Data/Healthy/2330.png
#   inflating: Data/Healthy/2337.png
#   inflating: Data/Healthy/2345.png
#   inflating: Data/Healthy/2347.png
#   inflating: Data/Healthy/2360.png
#   inflating: Data/Healthy/2364.png
#   inflating: Data/Healthy/2378.png
#   inflating: Data/Healthy/2383.png
#   inflating: Data/Healthy/2397.png
#   inflating: Data/Healthy/2402.png
#   inflating: Data/Healthy/2404.png
#   inflating: Data/Healthy/2407.png
#   inflating: Data/Healthy/2409.png
#   inflating: Data/Healthy/2420.png
#   inflating: Data/Healthy/2423.png
#   inflating: Data/Healthy/2435.png
#   inflating: Data/Healthy/2439.png
#   inflating: Data/Healthy/2440.png
#   inflating: Data/Healthy/2452.png
#   inflating: Data/Healthy/2454.png
#   inflating: Data/Healthy/2460.png
#   inflating: Data/Healthy/2462.png
#   inflating: Data/Healthy/2465.png
#   inflating: Data/Healthy/2469.png
#   inflating: Data/Healthy/2470.png
#   inflating: Data/Healthy/2473.png
#   inflating: Data/Healthy/2474.png
#   inflating: Data/Healthy/2480.png
#   inflating: Data/Healthy/2485.png
#   inflating: Data/Healthy/2490.png
#   inflating: Data/Healthy/2492.png
#   inflating: Data/Healthy/2495.png
#   inflating: Data/Healthy/2500.png
#   inflating: Data/Healthy/2503.png
#   inflating: Data/Healthy/2510.png
#   inflating: Data/Healthy/2517.png
#   inflating: Data/Healthy/2523.png
#   inflating: Data/Healthy/2524.png
#   inflating: Data/Healthy/2525.png
#   inflating: Data/Healthy/2529.png
#   inflating: Data/Healthy/2544.png
#   inflating: Data/Healthy/2553.png
#   inflating: Data/Healthy/2560.png
#   inflating: Data/Healthy/2575.png
#   inflating: Data/Healthy/2580.png
#   inflating: Data/Healthy/2590.png
#   inflating: Data/Healthy/2598.png
#   inflating: Data/Healthy/2599.png
#   inflating: Data/Healthy/2600.png
#   inflating: Data/Healthy/2608.png
#   inflating: Data/Healthy/2615.png
#   inflating: Data/Healthy/2620.png
#   inflating: Data/Healthy/2622.png
#   inflating: Data/Healthy/2623.png
#   inflating: Data/Healthy/2627.png
#   inflating: Data/Healthy/2629.png
#   inflating: Data/Healthy/2635.png
#   inflating: Data/Healthy/2637.png
#   inflating: Data/Healthy/2638.png
#   inflating: Data/Healthy/2643.png
#   inflating: Data/Healthy/2652.png
#   inflating: Data/Healthy/2655.png
#   inflating: Data/Healthy/2657.png
#   inflating: Data/Healthy/2658.png
#   inflating: Data/Healthy/2659.png
#   inflating: Data/Healthy/2660.png
#   inflating: Data/Healthy/2664.png
#   inflating: Data/Healthy/2667.png
#   inflating: Data/Healthy/2672.png
#   inflating: Data/Healthy/2675.png
#   inflating: Data/Healthy/2680.png
#   inflating: Data/Healthy/2684.png
#   inflating: Data/Healthy/2698.png
#   inflating: Data/Healthy/2704.png
#   inflating: Data/Healthy/2717.png
#   inflating: Data/Healthy/2720.png
#   inflating: Data/Healthy/2730.png
#   inflating: Data/Healthy/2734.png
#   inflating: Data/Healthy/2748.png
#   inflating: Data/Healthy/2757.png
#   inflating: Data/Healthy/2760.png
#   inflating: Data/Healthy/2763.png
#   inflating: Data/Healthy/2764.png
#   inflating: Data/Healthy/2767.png
#   inflating: Data/Healthy/2768.png
#   inflating: Data/Healthy/2769.png
#   inflating: Data/Healthy/2772.png
#   inflating: Data/Healthy/2773.png
#   inflating: Data/Healthy/2774.png
#   inflating: Data/Healthy/2779.png
#   inflating: Data/Healthy/2795.png
#   inflating: Data/Healthy/2798.png
#   inflating: Data/Healthy/2802.png
#   inflating: Data/Healthy/2822.png
#   inflating: Data/Healthy/2823.png
#   inflating: Data/Healthy/2824.png
#   inflating: Data/Healthy/2830.png
#   inflating: Data/Healthy/2833.png
#   inflating: Data/Healthy/2835.png
#   inflating: Data/Healthy/2842.png
#   inflating: Data/Healthy/2848.png
#   inflating: Data/Healthy/2849.png
#   inflating: Data/Healthy/2860.png
#   inflating: Data/Healthy/2864.png
#   inflating: Data/Healthy/2870.png
#   inflating: Data/Healthy/2874.png
#   inflating: Data/Healthy/2883.png
#   inflating: Data/Healthy/2885.png
#   inflating: Data/Healthy/2887.png
#   inflating: Data/Healthy/2895.png
#   inflating: Data/Healthy/2898.png
#   inflating: Data/Healthy/2900.png
#   inflating: Data/Healthy/2910.png
#   inflating: Data/Healthy/2918.png
#   inflating: Data/Healthy/2919.png
#   inflating: Data/Healthy/2930.png
#   inflating: Data/Healthy/2933.png
#   inflating: Data/Healthy/2937.png
#   inflating: Data/Healthy/2938.png
#   inflating: Data/Healthy/2945.png
#   inflating: Data/Healthy/2953.png
#   inflating: Data/Healthy/2955.png
#   inflating: Data/Healthy/2958.png
#   inflating: Data/Healthy/2963.png
#   inflating: Data/Healthy/2969.png
#   inflating: Data/Healthy/2973.png
#   inflating: Data/Healthy/2983.png
#   inflating: Data/Healthy/2985.png
#   inflating: Data/Healthy/2997.png
#   inflating: Data/Healthy/2998.png
#   inflating: Data/Healthy/2999.png
#   inflating: Data/Healthy/3004.png
#   inflating: Data/Healthy/3013.png
#   inflating: Data/Healthy/3015.png
#   inflating: Data/Healthy/3017.png
#   inflating: Data/Healthy/3022.png
#   inflating: Data/Healthy/3032.png
#   inflating: Data/Healthy/3033.png
#   inflating: Data/Healthy/3038.png
#   inflating: Data/Healthy/3039.png
#   inflating: Data/Healthy/3053.png
#   inflating: Data/Healthy/3054.png
#   inflating: Data/Healthy/3057.png
#   inflating: Data/Healthy/3060.png
#   inflating: Data/Healthy/3067.png
#   inflating: Data/Healthy/3074.png
#   inflating: Data/Healthy/3077.png
#   inflating: Data/Healthy/3105.png
#   inflating: Data/Healthy/3107.png
#   inflating: Data/Healthy/3110.png
#   inflating: Data/Healthy/3113.png
#   inflating: Data/Healthy/3115.png
#   inflating: Data/Healthy/3122.png
#   inflating: Data/Healthy/3127.png
#   inflating: Data/Healthy/3128.png
#   inflating: Data/Healthy/3139.png
#   inflating: Data/Healthy/3169.png
#   inflating: Data/Healthy/3182.png
#   inflating: Data/Healthy/3190.png
#   inflating: Data/Healthy/3193.png
#   inflating: Data/Healthy/3197.png
#   inflating: Data/Healthy/3199.png
#   inflating: Data/Healthy/3202.png
#   inflating: Data/Healthy/3210.png
#   inflating: Data/Healthy/3214.png
#   inflating: Data/Healthy/3217.png
#   inflating: Data/Healthy/3219.png
#   inflating: Data/Healthy/3232.png
#   inflating: Data/Healthy/3233.png
#   inflating: Data/Healthy/3240.png
#   inflating: Data/Healthy/3242.png
#   inflating: Data/Healthy/3243.png
#   inflating: Data/Healthy/3257.png
#   inflating: Data/Healthy/3265.png
#   inflating: Data/Healthy/3275.png
#   inflating: Data/Healthy/3279.png
#   inflating: Data/Healthy/3280.png
#   inflating: Data/Healthy/3290.png
#   inflating: Data/Healthy/3295.png
#   inflating: Data/Healthy/3297.png
#   inflating: Data/Healthy/3299.png
#   inflating: Data/Healthy/3312.png
#   inflating: Data/Healthy/3314.png
#   inflating: Data/Healthy/3318.png
#   inflating: Data/Healthy/3319.png
#   inflating: Data/Healthy/3322.png
#   inflating: Data/Healthy/3332.png
#   inflating: Data/Healthy/3347.png
#   inflating: Data/Healthy/3352.png
#   inflating: Data/Healthy/3355.png
#   inflating: Data/Healthy/3367.png
#   inflating: Data/Healthy/3372.png
#   inflating: Data/Healthy/3374.png
#   inflating: Data/Healthy/3379.png
#   inflating: Data/Healthy/3388.png
#   inflating: Data/Healthy/3390.png
#   inflating: Data/Healthy/3393.png
#   inflating: Data/Healthy/3407.png
#   inflating: Data/Healthy/3419.png
#   inflating: Data/Healthy/3423.png
#   inflating: Data/Healthy/3424.png
#   inflating: Data/Healthy/3429.png
#   inflating: Data/Healthy/3432.png
#   inflating: Data/Healthy/3439.png
#   inflating: Data/Healthy/3443.png
#   inflating: Data/Healthy/3445.png
#   inflating: Data/Healthy/3457.png
#   inflating: Data/Healthy/3458.png
#   inflating: Data/Healthy/3470.png
#   inflating: Data/Healthy/3473.png
#   inflating: Data/Healthy/3478.png
#   inflating: Data/Healthy/3482.png
#   inflating: Data/Healthy/3483.png
#   inflating: Data/Healthy/3487.png
#   inflating: Data/Healthy/3488.png
#   inflating: Data/Healthy/3492.png
#   inflating: Data/Healthy/3495.png
#   inflating: Data/Healthy/3502.png
#   inflating: Data/Healthy/3509.png
#   inflating: Data/Healthy/3515.png
#   inflating: Data/Healthy/3523.png
#   inflating: Data/Healthy/3527.png
#   inflating: Data/Healthy/3530.png
#   inflating: Data/Healthy/3540.png
#   inflating: Data/Healthy/3545.png
#   inflating: Data/Healthy/3548.png
#   inflating: Data/Healthy/3554.png
#   inflating: Data/Healthy/3560.png
#   inflating: Data/Healthy/3573.png
#   inflating: Data/Healthy/3578.png
#   inflating: Data/Healthy/3579.png
#   inflating: Data/Healthy/3587.png
#   inflating: Data/Healthy/3605.png
#   inflating: Data/Healthy/3607.png
#   inflating: Data/Healthy/3619.png
#   inflating: Data/Healthy/3620.png
#   inflating: Data/Healthy/3622.png
#   inflating: Data/Healthy/3630.png
#   inflating: Data/Healthy/3632.png
#   inflating: Data/Healthy/3633.png
#   inflating: Data/Healthy/3643.png
#   inflating: Data/Healthy/3645.png
#   inflating: Data/Healthy/3647.png
#   inflating: Data/Healthy/3652.png
#   inflating: Data/Healthy/3655.png
#   inflating: Data/Healthy/3658.png
#   inflating: Data/Healthy/3668.png
#   inflating: Data/Healthy/3673.png
#   inflating: Data/Healthy/3687.png
#   inflating: Data/Healthy/3689.png
#   inflating: Data/Healthy/3692.png
#   inflating: Data/Healthy/3694.png
#   inflating: Data/Healthy/3695.png
#   inflating: Data/Healthy/3708.png
#   inflating: Data/Healthy/3714.png
#   inflating: Data/Healthy/3725.png
#   inflating: Data/Healthy/3734.png
#   inflating: Data/Healthy/3738.png
#   inflating: Data/Healthy/3742.png
#   inflating: Data/Healthy/3743.png
#   inflating: Data/Healthy/3752.png
#   inflating: Data/Healthy/3755.png
#   inflating: Data/Healthy/3758.png
#   inflating: Data/Healthy/3760.png
#   inflating: Data/Healthy/3763.png
#   inflating: Data/Healthy/3765.png
#   inflating: Data/Healthy/3768.png
#   inflating: Data/Healthy/3780.png
#   inflating: Data/Healthy/3782.png
#   inflating: Data/Healthy/3783.png
#   inflating: Data/Healthy/3785.png
# Finished Downloading data

# %%
###################
# Parameters we use for the test
###################
params = {
  "batch": 32,
  "l1Tol2Features": 96,
  "l2tol3Features": 64,
  "epochs": 10,
  "lr": 0.08,
  "wtDecay": 0.04,
  "frozenChildren": 7,
  'momentum': 0.2
}

# %%
#######################
# Do Cross-validation in 5 layers
#######################

#####################
# Generate 5 folders with labels
#####################
def datasetGen(k=5):
  # csv label fields 
  fields = ['Name', 'label']

  # First we check if we have the directory created already
  # If yes, delete it and create it again
  # This is to avoid error when creating the lables
  # %cd /content/
  if os.path.exists('Dataset'):
    shutil.rmtree('Dataset')
  os.makedirs('Dataset')

  # Partition into five different subsets  
  # %cd Dataset/
  for i in range(k):
    os.makedirs(str(i))
    with open(os.path.join(str(i), "label.csv"), 'w+') as csvfile:
      csvwriter = csv.writer(csvfile) 
      csvwriter.writerow(fields)

########################
# Helper function to write label to csv
#######################
def csvWriteData(data, set):  
  with open(os.path.join('/content/Dataset', str(set), "label.csv"), 'a') as csvfile:   
      csvwriter = csv.writer(csvfile)  
      csvwriter.writerow(data)   

########################
# Helper function to sort images
#######################
def imgSort(dir, maxImg, index, label): 
  counter = [0,0,0,0,0]
  for dirpath, dirnames, filenames in os.walk(dir):
    for filename in [f for f in filenames if f.endswith(".png")]: 

      # Read image
      img = cv2.imread(os.path.join(dirpath, filename), cv2.IMREAD_UNCHANGED)
      if img is None:
        continue

      # Get Random Number
      subAssign = random.uniform(0, 5)

      # Folder 0
      if subAssign < 1 and counter[0] <= maxImg:
        counter[0] = counter[0] + 1
        csvWriteData([index, label], 0)
        cv2.imwrite(os.path.join('/content/Dataset/0', str(index)+'.png'), img)

      # Folder 1
      elif subAssign < 2 and counter[1] <= maxImg:
        counter[1] = counter[1] + 1
        csvWriteData([index, label], 1)
        cv2.imwrite(os.path.join('/content/Dataset/1', str(index)+'.png'), img)

      # Folder 2
      elif subAssign < 3 and counter[2] <= maxImg:
        counter[2] = counter[2] + 1
        csvWriteData([index,  label], 2)
        cv2.imwrite(os.path.join('/content/Dataset/2', str(index)+'.png'), img)
      
      # Folder 3
      elif subAssign < 4 and counter[3] <= maxImg:
        counter[3] = counter[3] + 1
        csvWriteData([index, label], 3)
        cv2.imwrite(os.path.join('/content/Dataset/3', str(index)+'.png'), img)

      # Folder 4
      else:
        counter[4] = counter[4] + 1
        csvWriteData([index, label], 4)
        cv2.imwrite(os.path.join('/content/Dataset/4', str(index)+'.png'), img)

      index += 1
  return index

# Create dataset structure
datasetGen(5)

# Distribute images
print("sorting images")
index = 1
index = imgSort('/content/Data/Covid', 2163, index, 0)
index = imgSort('/content/Data/Healthy', 909, index, 1)
index = imgSort('/content/Data/Others', 1497, index, 2)
print("done!")
print(index)
# Out:
# /content
# /content/Dataset
# sorting images
# done!
# 19031

# %%
############################
# Load our DataSet
############################
class Data:
    ########################
    # Constructor, initialize variables
    ########################
    def __init__(self, root):
        self.ROOT = root
        self.images, self.mn, self.std = self.read_images(self.ROOT)
        self.labels = self.read_labels(self.ROOT)
        
        # ======================================================================================
        # Composes several transforms together. Basically, do a bunch of transformation
        # ======================================================================================
        self.transform = transforms.Compose([
            # Convert a ``PIL Image`` or ``numpy.ndarray`` to tensor.                                    
            transforms.ToTensor(),
            # ===============================================
            # Normalize a tensor image with mean and standard deviation.
            # ===============================================            
            transforms.Normalize(self.mn, self.std)      
            ])
        
    ##################
    # Length of dataset
    ##################
    def __len__(self):
        # Return number of points in the dataset
        return len(self.images)

    ##################
    # Get Images and Label
    # Here we have to return the item requested by `idx`. The PyTorch DataLoader class will use this method to make an iterable for training/validation loop.
    ##################
    def __getitem__(self, idx):
        # Encounter some errors, img is a 1 channel, use a np.concatenate to make 3 channels
        img = self.transform(self.images[idx])
        img = np.concatenate((img, img, img), 0)
        label = self.labels[idx]
        return img, label
  
    # Read Images
    def read_images(self, path:str) -> list:
        imgs = []
        mn = 0
        std = 0
        count = 0
        for filename in sorted([f for f in os.listdir(path) if f.endswith(".png")], key=lambda f : int(f[:-4])): 
          img = cv2.imread(os.path.join(path, filename), cv2.IMREAD_UNCHANGED)
          img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
          imgs.append(img)
          mn += np.mean(img)
          std += np.var(img)
          count += 1
        mn /= count*255
        std = math.sqrt(std / (count)) / 255
        return imgs, mn, std
      
    # Read Labels
    def read_labels(self, path:str) -> list:
        labels = pd.read_csv(os.path.join(path, 'label.csv'))
        return labels.label

###################
# Create my 5 sets/cross-validation
###################
# Create datasets
print("Creating my 5 sets")
split = []
for i in range(5):
  split.append(Data(f'/content/Dataset/{i}'))

print("Finished Creating")
print("Size:" + str(len(split)))
# Out:
# Creating my 5 sets
# Finished Creating
# Size:5

# %%
#########################
# ML Network
#########################
class Network(nn.Module):
    def __init__(self):
        super().__init__()
        # TODO: [Transfer learning with pre-trained ResNet-50] 
        # 1) Define how many first layers of convolutoinal neural network (CNN) feature extractor in ResNet-50 to be "frozen" and 
        # 2) design your own fully-connected network (FCN) classifier.
        
        # 1) You will only refine last several layers of CNN feature extractor in ResNet-50 that mainly relate to high-level vision task. Determine how many first layers of ResNet-50 should be frozen to achieve best performances. Commented codes below will help you understand the architecture, i.e., "children", of ResNet-50.
        # 2) Design your own FCN classifier. Here I provide a sample of two-layer FCN.
        # Refer to PyTorch documentations of torch.nn to pick your layers. (https://pytorch.org/docs/stable/nn.html)
        # Some common Choices are: Linear, ReLU, Dropout, MaxPool2d, AvgPool2d
        # If you have many layers, consider using nn.Sequential() to simplify your code
        
        # Load pretrained ResNet-50
        self.model_resnet = models.resnet50(pretrained=True)
        
        # The code below can show children of ResNet-50
        #child_counter = 0
        #for child in model.children():
        #    print(" child", child_counter, "is -")
        #    print(child)
        #    child_counter += 1
        
        # ==================================================================
        # [Transfer learning with pre-trained ResNet-50] 
        # ==================================================================

        # ==================================================================
        # Determine how many first layers of ResNet-50 to freeze
        # ==================================================================
        '''
          How to decide how many layers to freeze?
        '''

        child_counter = 0
        for child in self.model_resnet.children():
            if child_counter < params['frozenChildren']:
                for param in child.parameters():
                    param.requires_grad = False
            elif child_counter == params['frozenChildren']:
                children_of_child_counter = 0
                for children_of_child in child.children():
                    if children_of_child_counter < 3:
                        for param in children_of_child.parameters():
                            param.requires_grad = False
                    else:
                        children_of_child_counter += 1
            else:
                print("child ",child_counter," was not frozen")
            child_counter += 1
        
        # Set ResNet-50's FCN as an identity mapping
        num_fc_in = self.model_resnet.fc.in_features
        self.model_resnet.fc = nn.Identity()
        
        # ==================================================================
        # Design your own FCN
        # ==================================================================
        # Increase dimension and then decreate back
        self.fc1 = nn.Linear(num_fc_in, params['l1Tol2Features'], bias = 3) # from input of size num_fc_in to output of size ?
        self.bn1 = nn.BatchNorm1d(params['l1Tol2Features'])
        self.fc2 = nn.Linear(params['l1Tol2Features'], params['l2tol3Features'], bias = 3) # from hidden layer to 3 class scores
        self.bn2 = nn.BatchNorm1d(params['l2tol3Features'])
        self.fc3 = nn.Linear(params['l2tol3Features'], 3, bias = 3)

    def forward(self,x):
        # ==================================================================
        # Design your own network, implement forward pass here
        # ==================================================================\
      relu = nn.ReLU()
      
      with torch.no_grad():
          features = self.model_resnet(x)
  
      x = self.fc1(features) 
      x = self.bn1(x)
      x = relu(x)
      x = self.fc2(x)
      x = self.bn2(x)
      x = relu(x)
      x = self.fc3(x)
      
      return x

def train(model, loader, test, num_epoch, criterion, optimizer): # Train the model
    print("Start training...")
    saveData = []
    model.train() # Set the model to training mode

    ########################
    # Run epochs with this parameters
    ########################
    for i in range(num_epoch):
        running_loss = []
        testing_loss = []
        for batch, label in tqdm(loader, position=0, leave=True):
            batch = batch.to(device)
            label = label.to(device)
            optimizer.zero_grad() # Clear gradients from the previous iteration
            pred = model(batch) # This will call Network.forward() that you implement
            loss = criterion(pred, label) # Calculate the loss
            running_loss.append(loss.item())
            loss.backward() # Backprop gradients to all tensors in the network
            optimizer.step() # Update trainable weights

        ####################
        # Now, we don't update the gradient since we don't want to bias our testing data
        ####################
        with torch.no_grad():
          for batch, label in tq.tqdm(test):
            batch = batch.to(device)
            label = label.to(device)
            pred = model(batch)
            loss = criterion(pred, label)
            testing_loss.append(loss.item())

        # Print loss
        print("Epoch {} training loss:{}".format(i+1,np.mean(running_loss))) 
        print("Epoch {} testing loss:{}".format(i+1,np.mean(testing_loss))) 

        saveData.append((i+1, np.mean(running_loss)))
        saveData.append((i+1, np.mean(testing_loss)))

    print("Done!")
    return saveData

def evaluate(model, loader): # Evaluate accuracy on validation / test set
    model.eval() # Set the model to evaluation mode
    correct = 0
    with torch.no_grad(): # Do not calculate grident to speed up computation
        for batch, label in tqdm(loader, position=0, leave=True):
            batch = batch.to(device)
            label = label.to(device)
            pred = model(batch)
            correct += (torch.argmax(pred,dim=1)==label).sum().item()

    acc = correct/len(loader.dataset)
    print("Evaluation accuracy: {}".format(acc))
    return acc

# %%
########################
# Cross-Validation Load Data into 5 sections
########################
# First batch train/test
b1Train = DataLoader(ConcatDataset([split[1], split[2], split[3], split[4]]), batch_size=params["batch"], shuffle=True, drop_last=True)
b1Test = DataLoader(split[0], batch_size=params["batch"], shuffle=True, drop_last=True)

# Second batch train/test
b2Train = DataLoader(ConcatDataset([split[0], split[2], split[3], split[4]]), batch_size=params["batch"], shuffle=True, drop_last=True)
b2Test = DataLoader(split[1], batch_size=params["batch"], shuffle=True, drop_last=True)

# Third batch train/test
b3Train = DataLoader(ConcatDataset([split[0], split[1], split[3], split[4]]), batch_size=params["batch"], shuffle=True, drop_last=True)
b3Test = DataLoader(split[2], batch_size=params["batch"], shuffle=True, drop_last=True)

# Fourth batch train/test
b4Train = DataLoader(ConcatDataset([split[0], split[1], split[2], split[4]]), batch_size=params["batch"], shuffle=True, drop_last=True)
b4Test = DataLoader(split[3], batch_size=params["batch"], shuffle=True, drop_last=True)

# Fifth batch train/test
b5Train = DataLoader(ConcatDataset([split[0], split[1], split[2], split[3]]), batch_size=params["batch"], shuffle=True, drop_last=True)
b5Test = DataLoader(split[4], batch_size=params["batch"], shuffle=True, drop_last=True)

# Store train/test pairs in list
pairs = [(b1Train, b1Test), (b2Train, b2Test), (b3Train, b3Test), (b4Train, b4Test), (b5Train, b5Test)]

# %%
########################
# Cross-Validation Traind data
########################
batchAccuracies = []
device = "cuda" if torch.cuda.is_available() else "cpu" # Configure device
num_epochs = params['epochs']
criterion = nn.CrossEntropyLoss(reduction='mean')

dataList = []
for pair in pairs:
  
  model= Network().to(device)
  
  #optimizer = optim.Adadelta(model.parameters(), lr=0.01)
  optimizer =   optimizer = optim.SGD(
      filter(lambda p: p.requires_grad, model.parameters()), 
            lr = params['lr'],
            #weight_decay = params['wtDecay'] #, 
            momentum = params['momentum'] # Specify optimizer and assign trainable parameters to it, weight_decay is L2 regularization strength (default: lr=1e-2, weight_decay=1e-4)
  )
  
  # Train on new batch
  data = train(model, pair[0], pair[1], num_epochs, criterion, optimizer)
  dataList.append(data)
  print("Evaluate on test set")

  # Save eval result
  batchAccuracies.append(evaluate(model, pair[1]))

  # Deleted model
  del model
print(f'Evaluation Accuracy for each batch: {batchAccuracies}')
print(f'Average accuracy: {sum(batchAccuracies) / len(batchAccuracies)}')
# Out:
#   0%|          | 2/477 [00:00<00:36, 13.07it/s]
# child  8  was not frozen
# child  9  was not frozen
# Start training...
# 100%|██████████| 477/477 [00:34<00:00, 13.68it/s]
# HBox(children=(FloatProgress(value=0.0, max=116.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:36, 13.18it/s]
# Epoch 1 training loss:0.5639838610680098
# Epoch 1 testing loss:0.4827015907343092
# 100%|██████████| 477/477 [00:35<00:00, 13.55it/s]
# HBox(children=(FloatProgress(value=0.0, max=116.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:36, 12.89it/s]
# Epoch 2 training loss:0.39233554370185864
# Epoch 2 testing loss:0.42412581140625066
# 100%|██████████| 477/477 [00:34<00:00, 13.66it/s]
# HBox(children=(FloatProgress(value=0.0, max=116.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:36, 12.94it/s]
# Epoch 3 training loss:0.3161369737245502
# Epoch 3 testing loss:0.3813497844184267
# 100%|██████████| 477/477 [00:35<00:00, 13.54it/s]
# HBox(children=(FloatProgress(value=0.0, max=116.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:35, 13.21it/s]
# Epoch 4 training loss:0.26620286382906594
# Epoch 4 testing loss:0.4002250783659261
# 100%|██████████| 477/477 [00:35<00:00, 13.58it/s]
# HBox(children=(FloatProgress(value=0.0, max=116.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:36, 13.03it/s]
# Epoch 5 training loss:0.22990256743954662
# Epoch 5 testing loss:0.39273625034196624
# 100%|██████████| 477/477 [00:35<00:00, 13.61it/s]
# HBox(children=(FloatProgress(value=0.0, max=116.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:35, 13.20it/s]
# Epoch 6 training loss:0.19579613625815828
# Epoch 6 testing loss:0.3784377884505124
# 100%|██████████| 477/477 [00:34<00:00, 13.65it/s]
# HBox(children=(FloatProgress(value=0.0, max=116.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:35, 13.33it/s]
# Epoch 7 training loss:0.17645644589055884
# Epoch 7 testing loss:0.3662112869707675
# 100%|██████████| 477/477 [00:34<00:00, 13.75it/s]
# HBox(children=(FloatProgress(value=0.0, max=116.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:35, 13.23it/s]
# Epoch 8 training loss:0.16046754070469793
# Epoch 8 testing loss:0.3767753130403058
# 100%|██████████| 477/477 [00:34<00:00, 13.72it/s]
# HBox(children=(FloatProgress(value=0.0, max=116.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:35, 13.31it/s]
# Epoch 9 training loss:0.14011461141693018
# Epoch 9 testing loss:0.3333545721874669
# 100%|██████████| 477/477 [00:34<00:00, 13.80it/s]
# HBox(children=(FloatProgress(value=0.0, max=116.0), HTML(value='')))
#   2%|▏         | 2/116 [00:00<00:07, 14.75it/s]
# Epoch 10 training loss:0.13147951865400845
# Epoch 10 testing loss:0.3392819780856371
# Done!
# Evaluate on test set
# 100%|██████████| 116/116 [00:07<00:00, 14.76it/s]
# Evaluation accuracy: 0.9035017375033414
#   0%|          | 2/477 [00:00<00:34, 13.66it/s]
# child  8  was not frozen
# child  9  was not frozen
# Start training...
# 100%|██████████| 477/477 [00:34<00:00, 13.68it/s]
# HBox(children=(FloatProgress(value=0.0, max=117.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:34, 13.60it/s]
# Epoch 1 training loss:0.5667786297370803
# Epoch 1 testing loss:0.4625748420118267
# 100%|██████████| 477/477 [00:34<00:00, 13.78it/s]
# HBox(children=(FloatProgress(value=0.0, max=117.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:35, 13.24it/s]
# Epoch 2 training loss:0.3952850640382407
# Epoch 2 testing loss:0.39770485944727546
# 100%|██████████| 477/477 [00:34<00:00, 13.68it/s]
# HBox(children=(FloatProgress(value=0.0, max=117.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:35, 13.24it/s]
# Epoch 3 training loss:0.3169642861471736
# Epoch 3 testing loss:0.3971409867716651
# 100%|██████████| 477/477 [00:34<00:00, 13.82it/s]
# HBox(children=(FloatProgress(value=0.0, max=117.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:36, 13.02it/s]
# Epoch 4 training loss:0.2652859012410826
# Epoch 4 testing loss:0.3671686570359092
# 100%|██████████| 477/477 [00:34<00:00, 13.79it/s]
# HBox(children=(FloatProgress(value=0.0, max=117.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:34, 13.62it/s]
# Epoch 5 training loss:0.22656369071055507
# Epoch 5 testing loss:0.3885435241027775
# 100%|██████████| 477/477 [00:34<00:00, 13.75it/s]
# HBox(children=(FloatProgress(value=0.0, max=117.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:35, 13.40it/s]
# Epoch 6 training loss:0.20009586857768474
# Epoch 6 testing loss:0.367244765544549
# 100%|██████████| 477/477 [00:34<00:00, 13.79it/s]
# HBox(children=(FloatProgress(value=0.0, max=117.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:35, 13.57it/s]
# Epoch 7 training loss:0.1792768862770101
# Epoch 7 testing loss:0.35252699052166736
# 100%|██████████| 477/477 [00:34<00:00, 13.80it/s]
# HBox(children=(FloatProgress(value=0.0, max=117.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:35, 13.38it/s]
# Epoch 8 training loss:0.16120427045619712
# Epoch 8 testing loss:0.34759638178297597
# 100%|██████████| 477/477 [00:34<00:00, 13.85it/s]
# HBox(children=(FloatProgress(value=0.0, max=117.0), HTML(value='')))
#   0%|          | 2/477 [00:00<00:35, 13.38it/s]
# Epoch 9 training loss:0.14960555155494054
# Epoch 9 testing loss:0.34471799105278444
# 100%|██████████| 477/477 [00:34<00:00, 13.84it/s]
# HBox(children=(FloatProgress(value=0.0, max=117.0), HTML(value='')))
#   2%|▏         | 2/117 [00:00<00:08, 14.34it/s]
# Epoch 10 training loss:0.1335246145736965
# Epoch 10 testing loss:0.35959411113180667
# Done!
# Evaluate on test set
# 100%|██████████| 117/117 [00:07<00:00, 14.81it/s]
# Evaluation accuracy: 0.9013070152040544
#   0%|          | 2/474 [00:00<00:34, 13.73it/s]
# child  8  was not frozen
# child  9  was not frozen
# Start training...
# 100%|██████████| 474/474 [00:34<00:00, 13.83it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   0%|          | 2/474 [00:00<00:34, 13.55it/s]
# Epoch 1 training loss:0.5685876556338137
# Epoch 1 testing loss:0.4590977206200111
# 100%|██████████| 474/474 [00:34<00:00, 13.82it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   0%|          | 2/474 [00:00<00:35, 13.40it/s]
# Epoch 2 training loss:0.3936316731389816
# Epoch 2 testing loss:0.41922677414757864
# 100%|██████████| 474/474 [00:34<00:00, 13.77it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   0%|          | 2/474 [00:00<00:35, 13.44it/s]
# Epoch 3 training loss:0.31358383174686993
# Epoch 3 testing loss:0.38275048718983384
# 100%|██████████| 474/474 [00:34<00:00, 13.84it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   0%|          | 2/474 [00:00<00:35, 13.39it/s]
# Epoch 4 training loss:0.26803874167837677
# Epoch 4 testing loss:0.3585367703638157
# 100%|██████████| 474/474 [00:34<00:00, 13.86it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   0%|          | 2/474 [00:00<00:38, 12.19it/s]
# Epoch 5 training loss:0.22388491032935898
# Epoch 5 testing loss:0.3403673756147633
# 100%|██████████| 474/474 [00:34<00:00, 13.57it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   0%|          | 2/474 [00:00<00:35, 13.15it/s]
# Epoch 6 training loss:0.21139740807157528
# Epoch 6 testing loss:0.3554962323743756
# 100%|██████████| 474/474 [00:34<00:00, 13.74it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   0%|          | 2/474 [00:00<00:35, 13.27it/s]
# Epoch 7 training loss:0.172338310122207
# Epoch 7 testing loss:0.35809047081891227
# 100%|██████████| 474/474 [00:34<00:00, 13.81it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   0%|          | 2/474 [00:00<00:35, 13.18it/s]
# Epoch 8 training loss:0.16210525482107063
# Epoch 8 testing loss:0.35235156250350613
# 100%|██████████| 474/474 [00:34<00:00, 13.84it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   0%|          | 2/474 [00:00<00:35, 13.26it/s]
# Epoch 9 training loss:0.13488518263956037
# Epoch 9 testing loss:0.3761134096930007
# 100%|██████████| 474/474 [00:35<00:00, 13.39it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   2%|▏         | 2/119 [00:00<00:08, 14.33it/s]
# Epoch 10 training loss:0.1232037218012513
# Epoch 10 testing loss:0.37321517679120314
# Done!
# Evaluate on test set
# 100%|██████████| 119/119 [00:08<00:00, 14.67it/s]
# Evaluation accuracy: 0.8961377870563675
#   0%|          | 2/473 [00:00<00:34, 13.58it/s]
# child  8  was not frozen
# child  9  was not frozen
# Start training...
# 100%|██████████| 473/473 [00:34<00:00, 13.71it/s]
# HBox(children=(FloatProgress(value=0.0, max=121.0), HTML(value='')))
#   0%|          | 2/473 [00:00<00:35, 13.25it/s]
# Epoch 1 training loss:0.5764958947644929
# Epoch 1 testing loss:0.4654966332942001
# 100%|██████████| 473/473 [00:34<00:00, 13.73it/s]
# HBox(children=(FloatProgress(value=0.0, max=121.0), HTML(value='')))
#   0%|          | 2/473 [00:00<00:35, 13.42it/s]
# Epoch 2 training loss:0.39747979693571556
# Epoch 2 testing loss:0.40445007396138405
# 100%|██████████| 473/473 [00:34<00:00, 13.72it/s]
# HBox(children=(FloatProgress(value=0.0, max=121.0), HTML(value='')))
#   0%|          | 2/473 [00:00<00:35, 13.27it/s]
# Epoch 3 training loss:0.3158526654349321
# Epoch 3 testing loss:0.3666081999944261
# 100%|██████████| 473/473 [00:34<00:00, 13.75it/s]
# HBox(children=(FloatProgress(value=0.0, max=121.0), HTML(value='')))
#   0%|          | 2/473 [00:00<00:34, 13.51it/s]
# Epoch 4 training loss:0.2740511990233027
# Epoch 4 testing loss:0.3407542531894258
# 100%|██████████| 473/473 [00:34<00:00, 13.68it/s]
# HBox(children=(FloatProgress(value=0.0, max=121.0), HTML(value='')))
#   0%|          | 2/473 [00:00<00:35, 13.23it/s]
# Epoch 5 training loss:0.23040728756161624
# Epoch 5 testing loss:0.3735032028649464
# 100%|██████████| 473/473 [00:34<00:00, 13.72it/s]
# HBox(children=(FloatProgress(value=0.0, max=121.0), HTML(value='')))
#   0%|          | 2/473 [00:00<00:35, 13.26it/s]
# Epoch 6 training loss:0.20312295660345045
# Epoch 6 testing loss:0.3155863131742832
# 100%|██████████| 473/473 [00:34<00:00, 13.62it/s]
# HBox(children=(FloatProgress(value=0.0, max=121.0), HTML(value='')))
#   0%|          | 2/473 [00:00<00:35, 13.16it/s]
# Epoch 7 training loss:0.1831318850158448
# Epoch 7 testing loss:0.33520139384368236
# 100%|██████████| 473/473 [00:34<00:00, 13.68it/s]
# HBox(children=(FloatProgress(value=0.0, max=121.0), HTML(value='')))
#   0%|          | 2/473 [00:00<00:34, 13.57it/s]
# Epoch 8 training loss:0.15722392046583883
# Epoch 8 testing loss:0.3510730594150291
# 100%|██████████| 473/473 [00:34<00:00, 13.71it/s]
# HBox(children=(FloatProgress(value=0.0, max=121.0), HTML(value='')))
#   0%|          | 2/473 [00:00<00:35, 13.26it/s]
# Epoch 9 training loss:0.14864537281320916
# Epoch 9 testing loss:0.3376221983762812
# 100%|██████████| 473/473 [00:34<00:00, 13.66it/s]
# HBox(children=(FloatProgress(value=0.0, max=121.0), HTML(value='')))
#   2%|▏         | 2/121 [00:00<00:08, 13.88it/s]
# Epoch 10 training loss:0.13716518596192748
# Epoch 10 testing loss:0.3200704195528976
# Done!
# Evaluate on test set
# 100%|██████████| 121/121 [00:08<00:00, 14.62it/s]
# Evaluation accuracy: 0.905019305019305
#   0%|          | 2/475 [00:00<00:35, 13.22it/s]
# child  8  was not frozen
# child  9  was not frozen
# Start training...
# 100%|██████████| 475/475 [00:34<00:00, 13.80it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   0%|          | 2/475 [00:00<00:35, 13.28it/s]
# Epoch 1 training loss:0.5636190925460113
# Epoch 1 testing loss:0.44456289520784587
# 100%|██████████| 475/475 [00:34<00:00, 13.71it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   0%|          | 2/475 [00:00<00:35, 13.34it/s]
# Epoch 2 training loss:0.39788827488296913
# Epoch 2 testing loss:0.4035196269259733
# 100%|██████████| 475/475 [00:34<00:00, 13.72it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   0%|          | 2/475 [00:00<00:35, 13.16it/s]
# Epoch 3 training loss:0.3171828870867428
# Epoch 3 testing loss:0.37883956404794167
# 100%|██████████| 475/475 [00:34<00:00, 13.61it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
# 100%|██████████| 475/475 [00:34<00:00, 13.73it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   0%|          | 2/475 [00:00<00:35, 13.33it/s]
# Epoch 5 training loss:0.22877381557696744
# Epoch 5 testing loss:0.3611961991346183
# 100%|██████████| 475/475 [00:34<00:00, 13.73it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   0%|          | 2/475 [00:00<00:35, 13.32it/s]
# Epoch 6 training loss:0.20065768648135035
# Epoch 6 testing loss:0.3361576133791138
# 100%|██████████| 475/475 [00:34<00:00, 13.76it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   0%|          | 2/475 [00:00<00:35, 13.33it/s]
# Epoch 7 training loss:0.1803480744597159
# Epoch 7 testing loss:0.3342970866365593
# 100%|██████████| 475/475 [00:34<00:00, 13.74it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   0%|          | 2/475 [00:00<00:35, 13.15it/s]
# Epoch 8 training loss:0.1594827551394701
# Epoch 8 testing loss:0.3469560724221358
# 100%|██████████| 475/475 [00:34<00:00, 13.70it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   0%|          | 2/475 [00:00<00:36, 13.09it/s]
# Epoch 9 training loss:0.15256422710261847
# Epoch 9 testing loss:0.34595682750604734
# 100%|██████████| 475/475 [00:34<00:00, 13.69it/s]
# HBox(children=(FloatProgress(value=0.0, max=119.0), HTML(value='')))
#   2%|▏         | 2/119 [00:00<00:08, 14.16it/s]
# Epoch 10 training loss:0.12345651047696408
# Epoch 10 testing loss:0.3369880584107728
# Done!
# Evaluate on test set
# 100%|██████████| 119/119 [00:08<00:00, 14.67it/s]
# Evaluation accuracy: 0.8985090243264452
# Evaluation Accuracy for each batch: [0.9035017375033414, 0.9013070152040544, 0.8961377870563675, 0.905019305019305, 0.8985090243264452]
# Average accuracy: 0.9008949738219029

# %%
##############
# Save Data into a CSV File
##############
with open('/content/params.csv', 'w+') as store:
  storeWrite = csv.writer(store, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
  #storeWrite.writerow(["tnMean", "tstMean", "tnStd", "tstStd", "batch", "l1Tol2Features", "epochs", "lr", "wtDecay", "frozenChildren"])
  for key, val in params.items():
    storeWrite.writerow([key, val])
  storeWrite.writerow(['epochNum', 'loss'])
  storeWrite.writerows(saveData)
  storeWrite.writerow(['Accuracy', batchAccuracies])
